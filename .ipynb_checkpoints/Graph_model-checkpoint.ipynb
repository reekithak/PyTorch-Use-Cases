# %% [markdown]
# # Preprocessing + Embedding + Model Building.

# %%
import math
import pandas as pd
import numpy as np
import networkx as nx
import time as time
import pickle
import winsound
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 5000 # Set Duration To 1000 ms == 1 second
#For Loading intermediate libraries
def save_obj(obj, name ):
    with open(r"D:\working repos\Pickle Files\ "+ str(name) + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
def load_obj(name):
    with open(r"D:\working repos\Pickle Files\ "+ str(name) + '.pkl', 'rb') as f:
        return pickle.load(f)
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **1.) Preprocessing**

# %% [markdown]
# Fetching the huge dataset from sql , query by query ( To make it managable )

# %%
import sqlite3
from tqdm import tqdm
from functools import partial

sql_queries = []
row_counter = 0

def create_database(db="drugs"):
    con = sqlite3.connect(f"./DB/{db}.db")
    return con

def transaction_builder(connection, cursor, sql):
    global sql_queries
    sql_queries.append(sql)
    # print(sql_queries)
    if len(sql_queries) > 1000:
        cursor.execute("BEGIN TRANSACTION")
        for s in sql_queries:
            try:
                cursor.execute(s)
            except Exception as e:
                print(s)
                print("[INSERT LOG]", e)
        connection.commit()
        sql_queries = []

def create_table(connection, cursor, query):
    cur = connection.cursor()
    try:
        cur.execute(query)
        connection.commit()
        return True
    except Exception as e:
        print("Error Creating table")
        print(f"[INSERT LOG] {e}")
        return False

connection = create_database()
cursor = connection.cursor()
table = create_table(connection, cursor, query="CREATE TABLE IF NOT EXISTS drug_interaction(cid text, pbdid text, target text,  ki text, ic50 text, kd text);")
if table:
    print("Table Found/Created")
    print("Inserting Values...")
    insert_logic = r'INSERT INTO drug_interaction values("{}", "{}", "{}", "{}", "{}", "{}");'
    transact = partial(transaction_builder, connection=connection, cursor=cursor)
    with open("../build1/dataset/BindingDB_All.tsv", "r", buffering=1000) as f:
        for row in f:
            if row_counter == 0:
                row_counter += 1
            else:
                data = row.split("\t")
                targets = data[38].split(",")
                target = [target for target in targets if target != ""]
                if len(target): 
                    target = target[0]
                else:
                    target = ""
                insert_statement = insert_logic.format(data[28], target, data[6], data[8], data[9], data[10])
                # print(insert_statement)
                transact(sql=insert_statement)
                row_counter += 1
            if row_counter % 100000 == 0:
                print(f"{row_counter} rows inserted")

# %% [markdown]
# Processing the acquired dataset.

# %%
import pandas as pd
import sqlite3
import numpy as np
import math
import numpy as np
import networkx as nx
import time as time

# %%
#my_add
try:
    df = pd.read_csv(r'C:\Users\Akhil Sanker\Downloads\Compressed\BindingDB_All.tsv',sep='\t',chunksize=50,usecols=['PubChem CID','Target Name Assigned by Curator or DataSource','Ki (nM)','IC50 (nM)','Kd (nM)'])
except Exception as e:
    print(e)
var=1
for i in range(10):
    if i==0:
        var=1
    else:
        pass
    try:

        for df in new:
            df.to_csv('file.csv', sep=',', mode='a')
    except:
        print("Error : "+str(var))
        var+=1
        pass
for i in range(10):
    try:
        file1 =  pd.read_csv("file.csv")
    except Exception as e:
        print(e)

# %%
try:
    temp_work_file_new = file1[['PubChem CID','Target Name Assigned by Curator or DataSource','Ki (nM)','IC50 (nM)','Kd (nM)']]
    temp_work_file_new.to_csv("temp_work_file_new.csv")
    #tmp_wrk = temp_work_file_new.loc[temp_work_file_new['PubChem CID']!='PubChem CID']
except Exception as e:
    print(e)
df = temp_work_file_new

# %%
tmp_wrk = temp_work_file_new.loc[temp_work_file_new['PubChem CID']!='PubChem CID']
tmp_wrk.drop_duplicates(inplace=True)
tmp_wrk.drop_duplicates(subset='PubChem CID',inplace=True)
tmp_wrk.dropna(subset=['PubChem CID'],inplace=True)

# %%
tdf_a = tmp_wrk[['PubChem CID','Target Name Assigned by Curator or DataSource']]
tdf_b = tmp_wrk[['Ki (nM)','IC50 (nM)','Kd (nM)']]
tdf_b.fillna('99999',inplace=True)

# %%
tb_list_1 = tdf_b['Ki (nM)']
tb_list_2 = tdf_b['IC50 (nM)']
tb_list_3 = tdf_b['Kd (nM)']
ki_list = []
ic_list = []
kd_list = []
for x in tb_list_1:
    if '<' in x or '>' in x or '#' in x:
        x=str(float(x[1:])+0.5)
        
    ki_list.append(x)
for y in tb_list_2:
    if '<' in y or '>' in y or '#' in y:
        y=str(float(y[1:])+0.5)
        
    ic_list.append(y)
for z in tb_list_3:
    if '<' in z or '>' in z or '#' in z:
        z=str(float(z[1:])+0.5)
        
    kd_list.append(z)

#Number issue sortedd..Converted all to numbers.

# %%
tb_final = pd.DataFrame()
tb_final['Ki (nM)'] = ki_list
tb_final['IC50 (nM)'] = ic_list
tb_final['Kd (nM)'] = kd_list
tdf_a.reset_index(inplace=True)
tdf_new = pd.concat([tdf_a ,tb_final],axis=1)
try:
    tdf_new.drop('index',axis=1 ,inplace=True)
except:
    pass
out_df = tdf_new.loc[(tdf_new['Ki (nM)']=='99999') &(tdf_new['Kd (nM)']=='99999') & (tdf_new['IC50 (nM)']=='99999')]
part_cleaned = pd.concat([tdf_new,out_df,out_df]).drop_duplicates(keep=False)
part_cleaned['min'] = part_cleaned[['Ki (nM)','IC50 (nM)','Kd (nM)']].min(axis=1)
part_cleaned #Cleaned number issue,.. removed 3==nan , added minimum.
# Out:
#        PubChem CID Target Name Assigned by Curator or DataSource Ki (nM)  \
# 0          3081361                                HIV-1 Protease    0.24
# 1          5327236                                HIV-1 Protease    0.25
# 2          5327235                                HIV-1 Protease    0.41
# 3          5327234                                HIV-1 Protease     0.8
# 4          3009319                                HIV-1 Protease    0.99
# ...            ...                                           ...     ...
# 790477    76318239                          Acetylcholinesterase   99999
# 790478    76336413                          Acetylcholinesterase   99999
# 790479    76321936                          Acetylcholinesterase   99999
# 790480    76329133                          Acetylcholinesterase   99999
# 790481    76311049                 Butyrylcholinesterase (BuChE)   99999
#
#        IC50 (nM) Kd (nM)       min
# 0          99999   99999      0.24
# 1          99999   99999      0.25
# 2          99999   99999      0.41
# 3          99999   99999      0.80
# 4          99999   99999      0.99
# ...          ...     ...       ...
# 790477     39110   99999  39110.00
# 790478   50000.5   99999  50000.50
# 790479       180   99999    180.00
# 790480     50830   99999  50830.00
# 790481     18360   99999  18360.00
#
# [710085 rows x 6 columns]

# %%
cid_target_dict  = part_cleaned.groupby('PubChem CID')['Target Name Assigned by Curator or DataSource'].apply(list).to_dict()

# %%
len(cid_target_dict.keys())
# Out:
# 710085

# %%
part_cleaned
# Out:
#        PubChem CID Target Name Assigned by Curator or DataSource Ki (nM)  \
# 0          3081361                                HIV-1 Protease    0.24
# 1          5327236                                HIV-1 Protease    0.25
# 2          5327235                                HIV-1 Protease    0.41
# 3          5327234                                HIV-1 Protease     0.8
# 4          3009319                                HIV-1 Protease    0.99
# ...            ...                                           ...     ...
# 790477    76318239                          Acetylcholinesterase   99999
# 790478    76336413                          Acetylcholinesterase   99999
# 790479    76321936                          Acetylcholinesterase   99999
# 790480    76329133                          Acetylcholinesterase   99999
# 790481    76311049                 Butyrylcholinesterase (BuChE)   99999
#
#        IC50 (nM) Kd (nM)       min
# 0          99999   99999      0.24
# 1          99999   99999      0.25
# 2          99999   99999      0.41
# 3          99999   99999      0.80
# 4          99999   99999      0.99
# ...          ...     ...       ...
# 790477     39110   99999  39110.00
# 790478   50000.5   99999  50000.50
# 790479       180   99999    180.00
# 790480     50830   99999  50830.00
# 790481     18360   99999  18360.00
#
# [710085 rows x 6 columns]

# %% [markdown]
# **Removing and creating a new dataset of lists values**

# %%
wrk = part_cleaned
wrk.reset_index(inplace=True)
wrk = wrk[['PubChem CID','index','Target Name Assigned by Curator or DataSource','min']]
split_df = wrk[(wrk['Target Name Assigned by Curator or DataSource'].str.contains(',' or'/'))]

# %% [markdown]
# **Deleting the above from the main dataframe pd.concat([df1, df2, df2]).drop_duplicates(keep=False)**

# %%
wrk_1 = pd.concat([wrk,split_df,split_df]).drop_duplicates(keep=False)
df1 = wrk_1
df2 = split_df
df1.shape,df2.shape
# Out:
# ((674618, 4), (35467, 4))

# %% [markdown]
# **Graph Building Phase-1**

# %%
target_list = list(df1['Target Name Assigned by Curator or DataSource'].unique())
#PART 1 - Casual Non-Complex List
t1 = time.time()
ele = 1
part_1_dict = {}
for targ in target_list: 
    print(str(ele)+str(" : ") + str(targ))
    tmp = df1.loc[df1['Target Name Assigned by Curator or DataSource']==targ]
    tmp_ids = tmp['PubChem CID'].to_list()
    Central_Node = targ
    tmp_ids.append(Central_Node)
    A = nx.Graph()
    A.add_nodes_from(tmp_ids)
    tmp_ids.pop()
    for pid in tmp_ids:
        val = float(tmp.loc[tmp['PubChem CID']==pid]['min'])
        A.add_edge(Central_Node,pid,weight=val)
    part_1_dict['{}'.format(ele)] = A
    ele+=1
    '''if ele ==50:
        break'''
t2 = time.time()
print(str("Time taken for : ") +str(len(target_list))+" is "+str(t2-t1)+" Seconds")
save_obj(part_1_dict,'df1')
# Out:
# 1 : HIV-1 Protease
# 2 : HIV-1 protease M1
# 3 : Cytochrome P450 3A
# 4 : Galactokinase (GALK)
# 5 : Caspase-3
# 6 : Caspase-1
# 7 : Autotaxin
# 8 : HIV-1 Reverse Transcriptase
# 9 : Orexin receptor type 1 (OX1)
# 10 : Hormone-sensitive lipase (HSL)
# 11 : Dual specificity mitogen-activated protein kinase kinase 1
# 12 : 11-beta-hydroxysteroid dehydrogenase 1
# 13 : Beta-lactamase (KPC-2)
# 14 : HIV-1 Reverse Transcriptase Mutant (Y181C)
# 15 : Focal adhesion kinase 1
# 16 : Tyrosine-protein kinase JAK2
# 17 : Amine oxidase [flavin-containing] A
# 18 : Reverse transcriptase protein
# 19 : Protein Kinase C
# 20 : HIV-1 Reverse Transcriptase Mutant (P236L)
# 21 : cAMP-Dependent Protein Kinase (PKA)
# 22 : Insulin receptor
# 23 : Epidermal growth factor receptor
# 24 : Platelet-derived growth factor receptor beta
# 25 : Protein kinase C alpha type
# 26 : Epoxide hydrolase 1
# 27 : Hepatocyte growth factor receptor
# 28 : Chymase
# 29 : Glucagon
# 30 : HCV NS3-NS4A Serine Proteinase
# 31 : Proto-oncogene tyrosine-protein kinase Src
# 32 : Cyclin-dependent kinase 2
# 33 : Fibroblast growth factor receptor 1
# 34 : Vascular endothelial growth factor receptor 1
# 35 : Neuraminidase A
# 36 : Vascular endothelial growth factor receptor 2
# 37 : Tyrosine-protein kinase ZAP-70
# 38 : Neuraminidase B
# 39 : Cyclin-Dependent Kinase 1 (CDK1)
# 40 : Cyclin-Dependent Kinase 4 (CDK4)
# 41 : CDK2/CycE
# 42 : Angiopoietin-1 receptor
# 43 : Cyclin-Dependent Kinase 2 (CDK2)
# 44 : Beta-secretase 1
# 45 : Cathepsin S
# 46 : Serine/threonine-protein kinase PAK 4
# 47 : Corticotropin releasing factor receptor 1
# 48 : Deoxyuridine 5&#39;-triphosphate nucleotidohydrolase (dUTPase)
# 49 : Cyclin-Dependent Kinase 6 (CDK6)
# 50 : Insulin-like growth factor I receptor
# 51 : Acetyl-CoA carboxylase 2 (ACC2)
# 52 : DNA-dependent protein kinase
# 53 : Epoxide hydrolase (MsEH)
# 54 : Cyclin-dependent kinase 1
# 55 : Muscarinic acetylcholine receptor M3
# 56 : Estrogen receptor
# 57 : Glutaminyl Cyclase
# 58 : Dopamine receptor
# 59 : E3 ubiquitin-protein ligase Mdm2
# 60 : Plasmepsin 2
# 61 : Cathepsin D
# 62 : cIAP-2 BIR3
# 63 : Glycogen synthase kinase-3 beta
# 64 : Glycogen synthase kinase-3
# 65 : Baculoviral IAP repeat-containing protein 3 (IAP1 BIR3)
# 66 : Serotonin (5-HT) receptor
# 67 : Anthrax Lethal Factor (LF)
# 68 : Aromatase (CYP19)
# 69 : Neutral endopeptidase (NEP)
# 70 : Coagulation factor X
# 71 : Enoyl-ACP Reductase (FabI)
# 72 : Tyrosine-protein kinase Lck
# 73 : Cytochrome P450 11B2 (CYP11B2)
# 74 : Cytochrome P450 17A1
# 75 : Cholinesterases
# 76 : Acetylcholinesterase
# 77 : Phosphodiesterase 9 (PDE9)
# 78 : Orexin receptor type 1
# 79 : Caspase-6
# 80 : Caspase-8
# 81 : Dihydroorotate dehydrogenase
# 82 : RAC-alpha serine/threonine-protein kinase AKT1
# 83 : Fibroblast growth factor receptor 3
# 84 : Butyrylcholinesterase (BChE)
# 85 : Monoamine oxidase
# 86 : Endochitinase B1
# 87 : Carbonic anhydrase 1
# 88 : Monoamine Oxidase Type A (MAO-A)
# 89 : Monoamine Oxidase Type B (MAO-B)
# 90 : Dipeptidyl peptidase 4
# 91 : 3C-like proteinase (3CL-PRO)
# 92 : Casein Kinase II
# 93 : Casein kinase II alpha
# 94 : Carbonic anhydrase 2
# 95 : 5-hydroxytryptamine receptor 2A
# 96 : Matrix metalloproteinase-1 (MMP1)
# 97 : Collagenase (ChC)
# 98 : Dipeptidyl peptidase IV
# 99 : Carbonic Anhydrase II Mutant (F131V)
# 100 : Falcipain-2
# 101 : Collagenase
# 102 : Aurora kinase A
# 103 : Serine/threonine-protein kinase Chk1
# 104 : Dipeptidyl peptidase VIII
# 105 : VEGFR-2 (KDR)
# 106 : Cytochrome P450 2A6
# 107 : Thrombin and coagulation factor X
# 108 : Serine/threonine-protein kinase pim-1
# 109 : Coagulation factor XI
# 110 : Phenylethanolamine N-methyltransferase
# 111 : Stromelysin-1
# 112 : XIAP-BIR3
# 113 : Lck
# 114 : Protein Farnesyltransferase (PFT)
# 115 : Mitogen-activated protein kinase 14
# 116 : Protein farnesyltransferase
# 117 : Protein farnesyl/geranylgeranyl transferase
# 118 : Protein-Tyrosine Phosphatase 1B (PTP1B)
# 119 : ABL
# 120 : Coagulation factor VII
# 121 : Receptor tyrosine-protein kinase erbB-2
# 122 : HIV-1 Protease B Subtype
# 123 : Trypsin
# 124 : Rho-associated protein kinase 1
# 125 : Urokinase-type plasminogen activator
# 126 : Mixed Lineage Kinase 1 (MLK1)
# 127 : Serine/threonine-protein kinase Aurora-A
# 128 : Tryptase
# 129 : Trypsin-1
# 130 : Plasminogen
# 131 : Adenosine Kinase (AK)
# 132 : Proto-oncogene tyrosine-protein kinase Src (aa 145-252)
# 133 : Cannabinoid receptor 2
# 134 : Phosphodiesterase Type 10 (PDE10A)
# 135 : Adenosine A2 receptor
# 136 : Phosphodiesterase Type 4 (PDE4B)
# 137 : MAP kinase p38
# 138 : Protein kinase B (Akt 1)
# 139 : Serine/threonine-protein kinase AKT2
# 140 : p110&alpha;/p85&alpha;
# 141 : Phosphodiesterase Type 3 (PDE3B)
# 142 : Phosphodiesterase Type 5 (PDE5A)
# 143 : Dihydroorotate Dehydrogenase (DHODH)
# 144 : HSP90 and hnRNPA2/B1
# 145 : Heat Shock Protein 90 (Hsp90)
# 146 : Mitogen-activated protein kinase 1
# 147 : Enoyl-ACP Reductase (InhA)
# 148 : Mitogen-activated protein kinase 10
# 149 : beta-Secretase (BACE-1)
# 150 : Aldose reductase (AR)
# 151 : Cathepsin B
# 152 : RAF-1
# 153 : Integrin alpha4beta1 (VLA-4)
# 154 : 3-phosphoinositide dependent protein kinase-1
# 155 : 3-phosphoinositide-dependent protein kinase 1 (51-359)
# 156 : 17-beta-Hydroxysteroid Dehydrogenase 1 (17-beta-HSD1)
# 157 : Methionine aminopeptidase 2
# 158 : Glutamate Carboxypeptidase II (GCPII)
# 159 : Macrophage colony-stimulating factor 1 receptor
# 160 : Methionine Aminopeptidase Type 1 (MetAP1)
# 161 : Methionine Aminopeptidase (MAP)
# 162 : Methionine Aminopeptidase
# 163 : Renin
# 164 : Dihydrofolate Reductase (DHFR)
# 165 : tRNA synthetase (PheRS)
# 166 : tRNA synthetase (GluRS)
# 167 : tRNA synthetase (AspRS)
# 168 : tRNA synthetase (TyrRS)
# 169 : tRNA synthetase (GlyRS)
# 170 : tRNA synthetase (IleRS)
# 171 : Androgen Receptor
# 172 : Dihydrofolate reductase
# 173 : Glucosylceramidase
# 174 : alpha-Glucosidase (alpha-Glu)
# 175 : HMG-CoA reductase
# 176 : Gamma-aminobutyric acid receptor subunit alpha-5 (GABA(A))
# 177 : Glucocorticoid receptor
# 178 : Androgen receptor
# 179 : Thymidylate Synthase (TS)
# 180 : Dihydrofolate Reductase-Thymidylate Synthase (DHFR-TS)
# 181 : Thymidylate synthase
# 182 : Thyroid Hormone Receptor (TR-alpha)
# 183 : Thyroid hormone receptor
# 184 : Integrin alpha2beta1
# 185 : Histone Deacetylase 6 (HDAC6)
# 186 : Histone deacetylase 1
# 187 : Inosine Monophosphate Dehydrogenase Type 1 (IMPDH1)
# 188 : Inosine Monophosphate Dehydrogenase Type 2 (IMPDH2)
# 189 : Ghrelin receptor
# 190 : Cathepsin K
# 191 : Liver X Receptor alpha (LXR-alpha)
# 192 : Thymidine Phosphorylase (TP)
# 193 : Papain
# 194 : Transcription Factor STAT3
# 195 : Vanilloid receptor
# 196 : Transient receptor potential cation channel subfamily V member 1
# 197 : Diacylglycerol O-acyltransferase 1 (DGAT1)
# 198 : Heat shock protein HSP 90-alpha
# 199 : Cyclin-Dependent Kinase 5 (CDK5)
# 200 : Corticotropin releasing factor receptor
# 201 : Cathepsin L1
# 202 : Delta-type opioid receptor
# 203 : Nociceptin/mu opioid receptor
# 204 : Substance-P receptor
# 205 : Cholecystokinin receptor
# 206 : Adenosine receptor A1
# 207 : Adenosine receptor A2a
# 208 : Cannabinoid receptor 1
# 209 : Fibronectin receptor beta/Integrin alpha-4
# 210 : Orotidine Monophosphate Decarboxylase (ODCase)
# 211 : 5-Hydroxytryptamine receptor 6 (5-HT6)
# 212 : 5-hydroxytryptamine receptor 1A (5-HT1A)
# 213 : D(2) dopamine receptor
# 214 : Bcl-2-like protein 1
# 215 : Angiotensin-converting enzyme
# 216 : TGF-beta receptor type I
# 217 : Galectin-1
# 218 : Galectin-3
# 219 : G protein-coupled receptor 44
# 220 : Prostaglandin D Synthase
# 221 : Neprilysin
# 222 : Pregnane X receptor (PXR)
# 223 : Peptide Deformylase
# 224 : DNA polymerase IIIC
# 225 : DNA Topoisomerase IV
# 226 : alpha-Methylacyl-CoA Racemase
# 227 : Matriptase
# 228 : Nociceptin receptor
# 229 : Thymidine kinase
# 230 : Mitogen-activated protein kinase kinase kinase 8
# 231 : Adenosine deaminase
# 232 : Monocarboxylate Transporter 1
# 233 : Peripheral-Type Benzodiazepine Receptor
# 234 : Protein Kinase YpkA
# 235 : Cathepsin B-Like Cysteine Protease (TbcatB)
# 236 : Purine nucleoside phosphorylase
# 237 : Methylthioadenosine Phosphorylase (MTAP)
# 238 : Asparaginyl Endopeptidase (AE)
# 239 : Monoamine transporters; Norepininephrine & dopamine
# 240 : Monoamine transporters; Norepinephrine & serotonin
# 241 : Sphingosine 1-phosphate receptor 1
# 242 : Arachidonate 15-lipoxygenase
# 243 : Arachidonate 5-lipoxygenase
# 244 : Lipoxygenase-1
# 245 : Prostaglandin G/H synthase (cyclooxygenase)
# 246 : 5-Lipoxygenase
# 247 : Sodium-dependent dopamine transporter
# 248 : Histamine receptor (H3)
# 249 : Histamine H4 receptor
# 250 : AICAR Tfase
# 251 : IMP Cyclohydrolase (IMPCH)
# 252 : GAR Tfase
# 253 : Gag-Pol polyprotein
# 254 : Factor XIIa
# 255 : DNA Ligase (MtuLigA)
# 256 : Anandamide amidohydrolase
# 257 : Fatty Acid Amide Hydrolase
# 258 : D-Amino Acid Oxidase (DAAO)
# 259 : Homoisocitrate Dehydrogenase (HICDH)
# 260 : Lactate Dehydrogenase
# 261 : Botulinum Neurotoxin Type A
# 262 : Immunophilin FKBP12
# 263 : Peptidyl-prolyl cis-trans isomerase FKBP1A
# 264 : HIV-1 Integrase
# 265 : alpha-Amylase
# 266 : Ubiquitin C-terminal Hydrolase L3 (UCH-L3)
# 267 : UDP-3-O-Acyl-GlcNAc Deacetylase (LpxC)
# 268 : TNF-alpha-Converting Enzyme
# 269 : ADAM17
# 270 : Hydroxycarboxylic acid receptor 2
# 271 : beta-Ketoacyl-ACP Synthase III (FabH)
# 272 : Equilibrative Nucleoside Transporter 1 (ENT1)
# 273 : Leukocyte elastase
# 274 : Kinesin Spindle Protein Eg5
# 275 : Calpain-1
# 276 : Aryl Hydrocarbon Receptor (AhR)
# 277 : Prostanoid IP receptor
# 278 : Cytosol aminopeptidase
# 279 : ADAMTS-5 (Aggrecanase-2)
# 280 : A disintegrin and metalloproteinase with thrombospondin motifs 4 (ADAMTS-4)
# 281 : A disintegrin and metalloproteinase with thrombospondin motifs 5 (ADAMTS-5)
# 282 : gamma-Aminobutyric Acid Type B Receptor
# 283 : Leukotriene A4 hydrolase
# 284 : Glycogen Phosphorylase (PYGL)
# 285 : Tyrosine-protein phosphatase non-receptor type 11
# 286 : Protein-Tyrosine Phosphatase SHP-2
# 287 : Fatty Acid Synthase
# 288 : DNA Gyrase
# 289 : BDNF/NT-3 growth factors receptor
# 290 : High affinity nerve growth factor receptor
# 291 : Acyl-CoA: cholesterol acyltransferase (ACAT)
# 292 : West Nile Virus (WNV) NS2B-NS3 Protease
# 293 : Serine/threonine-protein kinase PLK1
# 294 : Polo-Like Kinase 1
# 295 : Urea Amidohydrolase
# 296 : Ribosomal S6 Kinase 1 (RSK-1)
# 297 : Proto-oncogene tyrosine-protein kinase receptor Ret
# 298 : Ephrin type-B receptor 4
# 299 : Geranylgeranyl Diphosphate Synthase (GGPPS)
# 300 : ATP Phosphoribosyltransferase
# 301 : Serine/threonine-protein kinase B-raf
# 302 : Beta-2 adrenergic receptor and beta-3 adrenergic receptor
# 303 : Enoyl-ACP Reductase (PfENR)
# 304 : Adenosine Phosphosulfate Reductase (APSR)
# 305 : Rho-kinase (ROCK II)
# 306 : Protein kinase C theta type
# 307 : B-RAF V600E
# 308 : Epoxide Hydrolase B (EHB)
# 309 : Beta-1 adrenergic receptor
# 310 : Cytochrome P450 51(CYP51)
# 311 : Sodium-dependent serotonin transporter
# 312 : Inhibitor of nuclear factor kappa-B kinase subunit alpha
# 313 : Inhibitor of nuclear factor kappa-B kinase subunit beta
# 314 : RAF proto-oncogene serine/threonine-protein kinase
# 315 : Liver X Receptor beta (LXR-beta)
# 316 : Protein Tyrosine Phosphatase PTPB
# 317 : Histone Lysine Demethylase
# 318 : Tyrosine-protein kinase JAK3
# 319 : Aldo-keto reductase family 1 member C1
# 320 : Aurora kinase B
# 321 : Aurora Kinase A (Aurora-A)
# 322 : Prokineticin Receptor 1 (PKR1)
# 323 : G-protein Coupled Receptor 54
# 324 : MurD
# 325 : Apurinic-apyrimidinic endonuclease 1 (APE-1)
# 326 : Fatty-acid amide hydrolase 1
# 327 : Tyrosine-protein kinase ITK/TSK
# 328 : Carbonic Anhydrase XV
# 329 : Poly [ADP-ribose] polymerase 1
# 330 : Cdc7 Kinase
# 331 : Inhibitor of nuclear factor kappa-B kinase subunit epsilon
# 332 : HIV-1 Reverse Transcriptase Mutant (103N/181C)
# 333 : Histone-Arginine Methyltransferase CARM1
# 334 : ML-IAP-BIR
# 335 : Calcium-sensing receptor (CaSR)
# 336 : Liver X receptor (LXR alpha AND LXR beta)
# 337 : Trypanothione reductase
# 338 : Serine/threonine-protein kinase pim-2
# 339 : S-adenosylmethionine decarboxylase 1
# 340 : Matrix metalloproteinase-12 (MMP12)
# 341 : Peroxisome proliferator-activated receptor delta
# 342 : Peroxisome proliferator-activated receptor
# 343 : Peroxisome proliferator-activated receptor alpha (PPAR alpha)
# 344 : NAD-Dependent Deacetylase Sirtuin-1
# 345 : Glucagon receptor
# 346 : Amine oxidase [flavin-containing] B
# 347 : Ribosyldihydronicotinamide dehydrogenase [quinone]
# 348 : Carbonic Anhydrase (mtCA 3)
# 349 : HCV NS3 Helicase
# 350 : Sterol 14-alpha demethylase (CYP51)
# 351 : 5-hydroxytryptamine receptor 4 (5-HT4)
# 352 : Histone Deacetylase (pfHDAC-1)
# 353 : Runt-Related Transcription Factor 1 Isoform AML1C
# 354 : Melanin-concentrating hormone receptor
# 355 : MAP kinase-activated protein kinase 2
# 356 : MAPK-Activated Protein Kinase 2 (MK2)
# 357 : Bile acid receptor
# 358 : Non-structural protein 5B (NS5B)
# 359 : ABL Mutant (T315I)
# 360 : ALK tyrosine kinase receptor
# 361 : D-amino-acid oxidase
# 362 : Cyclin-dependent kinase 19
# 363 : SARS Coronavirus Coronavirus Papain-Like Protease
# 364 : Heme Oxygenase 1 (HO-1)
# 365 : Heat Shock 70kDa Protein 1
# 366 : MKP-3
# 367 : Pteridine Reductase 1 (PTR1)
# 368 : Kynurenine Aminotransferase 1/Glutamine Transaminase K
# 369 : beta-Hydroxyacyl-Acyl Carrier Protein Dehydratase (FabZ)
# 370 : Cathepsin L
# 371 : Serine/threonine-protein kinase D1
# 372 : 3-Phosphoinositide-Dependent Protein Kinase 1 (PDK1)
# 373 : Mitogen-Activated Protein Kinase 10 (JNK3)
# 374 : 11-beta-Hydroxysteroid Dehydrogenase 1 (11-beta-HSD1)
# 375 : cIAP-1 BIR3
# 376 : ATP-binding cassette sub-family G member 2
# 377 : Biotin Carboxylase
# 378 : Dengue Virus 1 (DENV1) NS2B-NS3 Protease
# 379 : Alpha-chymotrypsin
# 380 : Dengue Virus 2 (DENV2) NS2B-NS3 Protease
# 381 : Sortase A (SrtA)
# 382 : DNA Polymerase alpha
# 383 : HIV-1 Reverse Transcriptase RNase H
# 384 : PPIase Pin1
# 385 : Checkpoint Kinase (Chk2)
# 386 : Glycogen Phosphorylase (PYGM)
# 387 : Sarco/endoplasmic Reticulum Ca2+ ATPase 1
# 388 : Bfl-1
# 389 : MPI protein
# 390 : Serine/threonine-protein kinase pim-3
# 391 : Protein kinase C (PKC)
# 392 : Sodium-dependent noradrenaline transporter
# 393 : Dual Specificity Protein Phosphatase 1
# 394 : Cathepsin (B and K)
# 395 : NAD(P)H dehydrogenase [quinone] 1
# 396 : Peptidyl-prolyl cis-trans isomerase FKBP1B/Serine/threonine-protein kinase mTOR
# 397 : Vasopressin V2 receptor (V2)
# 398 : Vasopressin V2 Receptor
# 399 : Prostanoid EP1 Receptor
# 400 : Carbonic anhydrase
# 401 : ATP-dependent clamp loaders gp44/62
# 402 : Legumain
# 403 : Calcium-dependent protein kinase 1
# 404 : kinesin spindle protein
# 405 : Beta-mannosidase
# 406 : PI3K-alpha/ mTOR
# 407 : PI3K-alpha/ DNA-PK
# 408 : PI3K-alpha/ p110-delta
# 409 : Protein Wnt
# 410 : Phospholipase D (PLD)
# 411 : Methylthioadenosine Nucleosidase(MTAN)
# 412 : Beta-lactamase (CTX-M)
# 413 : Uracil-DNA glycosylase (UNG)
# 414 : Kaposi&#39;s sarcoma-associated herpesvirus (KSHV)
# 415 : Histone deacetylase 4
# 416 : Dual specificity protein kinase TTK
# 417 : Methylthioadenosine Nucleosidase (MTAN)
# 418 : Farnesyl diphosphate synthase
# 419 : Tyrosine-protein kinase BTK
# 420 : Scavenger mRNA-decapping enzyme (DcpS)
# 421 : Enoyl-[acyl-carrier-protein] reductase [NADH] (ftuFabl)
# 422 : Tryrosine-Protein Kinase (HCK) + Protein Nef (NEF)
# 423 : N-acetyl-beta-D-glucosaminidase (O-GlcNAcase)
# 424 : Tubulin--tyrosine ligase
# 425 : Cyclic AMP-dependent protein kinase (PKA)
# 426 : Retinoic acid receptor RXR-alpha
# 427 : Ethylene-forming enzyme (EFE)
# 428 : Metallo-beta-lactamase
# 429 : HIV-1 protease
# 430 : Serine/threonine-protein kinase MST2
# 431 : Vitamin D3 receptor
# 432 : Casein kinase I isoform delta
# 433 : Sphingosine 1-phosphate receptor 3
# 434 : Huntingtin
# 435 : fMet-Leu-Phe receptor 1/2
# 436 : cAMP-dependent protein kinase (PKA)
# 437 : diphosphomevalonate decarboxylase
# 438 : mevalonate kinase
# 439 : Dual specificity phosphatase Cdc25B
# 440 : Nuclear receptor ROR-alpha
# 441 : Steroidogenic Factor 1
# 442 : Rho-associated protein kinase 2
# 443 : Genome polyprotein
# 444 : Alkaline phosphatase placental-like
# 445 : Beta-lactamase AmpC
# 446 : Ubiquitin carboxyl-terminal hydrolase BAP1 (BRCA1-associated protein 1) (Cerebral protein 6).
# 447 : mothers against decapentaplegic homolog 3
# 448 : N-formyl peptide receptor 2
# 449 : Beta-hexosaminidase subunit beta (Hex B)
# 450 : Beta-hexosaminidase subunit alpha (HexA)
# 451 : Protein phosphatase 1 regulatory subunit 1A (PP1)
# 452 : Complement C1s
# 453 : RNA polymerase beta subunit (EC 2.7.7.6)
# 454 : Cathepsin G
# 455 : Opioid growth factor receptor-like protein 1
# 456 : Sphingosine 1-Phosphate Receptor 2
# 457 : Epoxide hydratase
# 458 : Galanin receptor 2
# 459 : Glyceraldehyde-3-phosphate dehydrogenase liver
# 460 : acetyl-CoA acetyltransferase/HMG-CoA reductase
# 461 : YopH
# 462 : Neuropeptide Y receptor type 1
# 463 : Transcription Factor STAT1
# 464 : STAT3
# 465 : X-linked inhibitor of apoptosis protein (XIAP)
# 466 : Aminoacyl-tRNA synthetase
# 467 : Hexokinase
# 468 : Myristoyl-CoA:protein N-myristoyltransferase (Nmt)
# 469 : Oligosaccharyl transferase (OT)
# 470 : electroneutral potassium-chloride cotransporter KCC2
# 471 : Tumor necrosis factor ligand superfamily member 10
# 472 : Eph receptor A4
# 473 : Hematopoietic protein-tyrosine phosphatase (HEPTP)
# 474 : heat shock 70kDa protein 8 isoform 2
# 475 : Valosin-containing protein
# 476 : hexokinase
# 477 : phosphomannomutase 2
# 478 : 3C-like protease
# 479 : Estradiol receptor beta (ER&#946;)
# 480 : Induced myeloid leukemia cell differentiation protein Mcl-1
# 481 : BZLF2
# 482 : DNA repair protein RAD51 homolog 1
# 483 : Dual specificity protein phosphatase (VHR)
# 484 : Beta lactamase
# 485 : Peptidyl-prolyl cis-trans isomerase
# 486 : Ubiquitin carboxyl-terminal hydrolase isozyme L1 (UCH-L1)
# 487 : Ubiquitin carboxyl-terminal hydrolase isozyme L3 (UCH-L3)
# 488 : Zinc aminopeptidase
# 489 : nucleotide-binding oligomerization domain containing 2
# 490 : ubiquitin-conjugating enzyme E2I
# 491 : neuronal munc18-1 binding protein
# 492 : Tyrosine-protein phosphatase non-receptor type 22
# 493 : plectin 1
# 494 : Opioid receptors; mu/kappa/delta
# 495 : core protein
# 496 : likely tRNA 2&#39;-phosphotransferase
# 497 : NS3
# 498 : M18 aspartyl aminopeptidase
# 499 : neutrophil cytosolic factor 1
# 500 : Kallikrein 5
# 501 : Cyclin-dependent kinase 4
# 502 : G1/S-specific cyclin-D1
# 503 : D-lactate dehydrogenase
# 504 : Cyclin-dependent kinase 5 regulatory subunit 1
# 505 : Coagulation Factor VIII
# 506 : Calmodulin
# 507 : Protein-glutamine gamma-glutamyltransferase 2 (TG2)
# 508 : Human herpesvirus 1 protease
# 509 : Tubulin
# 510 : leucine aminopeptidase
# 511 : large T antigen
# 512 : SUMO1 activating enzyme subunit 1
# 513 : Eukaryotic translation initiation factor 4H
# 514 : G-protein coupled receptor 55
# 515 : G-protein coupled receptor 35
# 516 : Voltage-gated calcium channel subunit alpha Cav2.2
# 517 : neuropeptides B/W receptor 1
# 518 : nucleotide-binding oligomerization domain containing 1
# 519 : Sphingosine 1-Phosphate Receptor 4
# 520 : Tumor necrosis factor
# 521 : BZLF1
# 522 : Cannabinoid receptor 1/Mu-type opioid receptor
# 523 : NADPH oxidase 1
# 524 : inward rectifier potassium channel 2
# 525 : photoreceptor-specific nuclear receptor
# 526 : Apelin receptor
# 527 : defective in Germ Line Development family member (gld-1)
# 528 : DNA damage-inducible transcript 3 protein
# 529 : ABL1(Q252H)
# 530 : UDP-galactopyranose mutase
# 531 : Uridine 5&#39;-diphosphate-galactopyranose mutase (UGM)
# 532 : Beta-ketoacyl-ACP synthase III (FabH)
# 533 : Cytochrome P450 1B1
# 534 : Progesterone receptor
# 535 : Kruppel-like factor 5
# 536 : envelope glycoprotein
# 537 : ATP-sensitive inward rectifier potassium channel 1
# 538 : protein phosphatase methylesterase 1
# 539 : Intestinal alkaline phosphatase
# 540 : Glutathione transferase omega 1
# 541 : insulin-degrading enzyme isoform 1 precursor
# 542 : Alpi
# 543 : NLRP3 protein
# 544 : DNA recombination protein RecA
# 545 : protein-arginine deiminase type-4
# 546 : alternatively spliced Trp4
# 547 : TPA: Essential protein of the mitochondrial intermembrane space
# 548 : ubiquitin-conjugating enzyme E2 N
# 549 : perilipin-1
# 550 : p53-Binding Protein HDMX
# 551 : Beta-galactosidase
# 552 : DNA dC->dU-editing enzyme APOBEC-3G
# 553 : putative hexokinase HKDC1
# 554 : cardiac alpha tropomyosin
# 555 : cysteine protease ATG4B isoform a
# 556 : glucose-6-phosphate dehydrogenase-6-phosphogluconolactonase
# 557 : Monoglyceride lipase (MGL)
# 558 : FtsZ
# 559 : TGM2/ cRaf Kinase
# 560 : TGM2/ Janus Kinase 3
# 561 : TGM2/ Tyrosine Phosphatase
# 562 : Putative farnesyl pyrophosphate synthase
# 563 : Olfactory receptor 17
# 564 : Methionine aminopeptidase (MetAP2)
# 565 : Nicotinate-nucleotide adenylyltransferase (NadD)
# 566 : Tyrosine-protein kinase ABL1
# 567 : Tyrosine-protein kinase Blk
# 568 : Hypoxia-inducible factor 1-alpha
# 569 : Nicotinamide phosphoribosyltransferase
# 570 : Dipeptidyl peptidase I
# 571 : Disulfide bond formation protein B (DsbB)
# 572 : Inosine-5-monophosphate dehydrogenase (IMPDH)
# 573 : Non-receptor tyrosine-protein kinase TYK2
# 574 : Alpha-1A adrenergic receptor
# 575 : Gamma-aminobutyric acid receptor subunit alpha-1 (GABA(A) alpha-1)
# 576 : Histamine H1 receptor
# 577 : Gamma-aminobutyric acid type B receptor subunit 1
# 578 : DRD1
# 579 : Muscarinic acetylcholine receptor M1
# 580 : 5-hydroxytryptamine receptor 1B
# 581 : Chitinase (chiA1)
# 582 : AcrAB-TolC
# 583 : Acidic mammalian chitinase (AMCase)
# 584 : Sentrin-specific protease 1 (SENP1)
# 585 : Leukotriene 2
# 586 : PACAP
# 587 : Histamine H2 receptor
# 588 : Topoisomerase II alpha (HuTopoII&#945;)
# 589 : Homeodomain-interacting protein kinase 2 (HIPK2)
# 590 : Extracellular signal-regulated kinase 5 (ERK5)
# 591 : Tyrosine kinase non-receptor protein 2
# 592 : HTH-type transcriptional regulator mgrA (MgrA)
# 593 : Bis(5'adenosyl)-triphosphatase
# 594 : UDP-N-acetylmuramoylalanine--D-glutamate ligase (MurgD)
# 595 : UDP-N-acetylmuramoyl-tripeptide--D-alanyl-D-alanine ligase (MurF)
# 596 : HDM2-p53 protein
# 597 : UDP-3-O-acyl-GlcNAc deacetylase (LpxC)
# 598 : Neuronal proto-oncogene tyrosine-protein kinase Src
# 599 : Viral IAP-associated factor 1 (VIAF)
# 600 : Somatostatin receptor type 1
# 601 : SSTR2
# 602 : Serotonin receptor 2a and 2c (5HT2A and 5HT2C)
# 603 : Alpha-2A adrenergic receptor
# 604 : Dopamine D2 receptor/Serotonin 2 (5-HT2) receptor
# 605 : SSTR4
# 606 : Adenylate cyclase
# 607 : 5-HT5
# 608 : Serotonin 1B/1D receptor
# 609 : Adenosine Receptors A2a (A2a)
# 610 : 5-hydroxytryptamine receptor 1D
# 611 : D(3) dopamine receptor
# 612 : HTR1D
# 613 : Muscarinic acetylcholine receptor M4
# 614 : Renal dipeptidase
# 615 : Leukotriene D4 Beta
# 616 : Adrenergic receptor alpha-2
# 617 : C-C chemokine receptor type 4 (CCR4)
# 618 : Hyaluronidase
# 619 : CCKBR
# 620 : D(1A) dopamine receptor
# 621 : Dopamine D5 receptor
# 622 : DRD2
# 623 : GRIA3
# 624 : Ionotropic glutamate receptor NMDA 1/2D
# 625 : n-AChR
# 626 : Oxytocin receptor
# 627 : Carboxypeptidase A1
# 628 : Muscarinic acetylcholine receptor M2
# 629 : Dopamine D2 receptor
# 630 : Adenosine A1 receptor
# 631 : Platelet activating factor receptor
# 632 : OPRK1
# 633 : Kappa-type opioid receptor
# 634 : HRH3
# 635 : Calcium channel
# 636 : BHE
# 637 : Prostanoid TP receptor
# 638 : Opioid receptors; mu & delta
# 639 : GABA A receptor alpha-1/beta-1/gamma-2
# 640 : GABA A Alpha2Beta1Gamma2
# 641 : Cholecystokinin B
# 642 : Sigma non-opioid intracellular receptor 1
# 643 : adrenergic Alpha2
# 644 : Dopamine D1 receptor
# 645 : Reverse transcriptase
# 646 : Dihydrofolate reductase (DHFR)
# 647 : Grp78
# 648 : Ketol-acid reductoisomerase
# 649 : Phosphopantetheine adenylyltransferase (PPAT)
# 650 : Serum paraoxonase/arylesterase 1
# 651 : EPHA4
# 652 : Porphobilinogen synthase
# 653 : PTGDR
# 654 : TBXA2R
# 655 : Cholecystokinin
# 656 : DOPAMINE
# 657 : Glutamate kainate
# 658 : Metabotropic glutamate receptor
# 659 : 5-HT1
# 660 : SSTR1
# 661 : Angiotensin II AT2
# 662 : Neurokinin 1 receptor
# 663 : Substance-K receptor
# 664 : Norepinephrine transporter
# 665 : Melatonin receptor
# 666 : 5-hydroxytryptamine receptor 2C
# 667 : Neuropeptide Y receptor type 2
# 668 : Neuromedin-K receptor
# 669 : HTR7
# 670 : HTR6
# 671 : Acetylcholinesterase (AChE)
# 672 : Phospholipase A2
# 673 : Metabotropic Glutamate 1a
# 674 : VIP peptides
# 675 : VIP
# 676 : Melanocyte-stimulating hormone receptor
# 677 : Melanocortin receptor 3 (MC3R)
# 678 : NT
# 679 : HTR4
# 680 : Serotonin receptor 2a and 2b (5HT2A and 5HT2B)
# 681 : 5-HT3A Serotonin Receptor
# 682 : AGTR1
# 683 : Beta-2 adrenergic receptor
# 684 : Serotonin 1d (5-HT1d) receptor
# 685 : 5-HT5B
# 686 : Alpha-2C adrenergic receptor
# 687 : Somatostatin receptor type 3
# 688 : Melatonin
# 689 : Adenosine receptor A3
# 690 : HTR3A
# 691 : GRIK4
# 692 : carboxy-terminal domain RNA polymerase II polypeptide A small phosphatase 1 isoform 1
# 693 : C-C chemokine receptor type 6 (CCR6)
# 694 : Toll-like receptor 9 (TLR9)
# 695 : Apoptotic peptidase activating factor 1
# 696 : SUMO/sentrin specific peptidase family member 8
# 697 : Voltage-gated potassium channel subunit Kv7.2
# 698 : Dopamine receptors; D2 & D4
# 699 : Golgi alpha-mannosidase II
# 700 : Catechol-O-methyltransferase
# 701 : phosphatase Cdc25
# 702 : Vascular endothelial growth factor receptor 3
# 703 : 1-deoxy-D-xylulose 5-phosphate reductoisomerase
# 704 : Acidic fibroblast growth factor
# 705 : Protein-tyrosine phosphatase 1B
# 706 : Somatostatin receptor type 2
# 707 : tRNA-guanine transglycosylase (TGT)
# 708 : Trans-sialidase
# 709 : Luteinizing Hormone-Releasing Hormone LHRH
# 710 : Heme Oxygenase 2 (HO-2)
# 711 : Pantothenate synthetase
# 712 : Histone acetyltransferase p300
# 713 : Alpha-fucosidase
# 714 : 5-HT2
# 715 : NPY1R
# 716 : Neuronal acetylcholine receptor subunit alpha-4
# 717 : Serotonin receptor (2b and 2c)
# 718 : Nicotinic Alpha-Bungarotoxin
# 719 : Metabotropic glutamate receptor 1
# 720 : GABA A Alpha4Beta2Gamma2
# 721 : Alpha-glucosidase MAL12
# 722 : NPY5R
# 723 : Neuropeptide Y receptor type 5 ( NPY Y5)
# 724 : Metabotropic glutamate receptor 2
# 725 : Metabotropic glutamate receptor 4 (mGlu4)
# 726 : 5-hydroxytryptamine receptor 7 (5HT7)
# 727 : Adenosine receptor A1 (A1)
# 728 : Gamma-aminobutyric acid receptor (GABA(A)) subunit alpha-4
# 729 : P2X purinoceptor 4
# 730 : Endothelin-1 receptor
# 731 : GALR1
# 732 : Metabotropic glutamate receptor 4 (mGluR4)
# 733 : HTR1A
# 734 : HTR1B
# 735 : AVPR1A
# 736 : 5-hydroxytryptamine receptor 1A (5HT1B)
# 737 : Tyrosinase
# 738 : Serotonin N-acetyltransferase (AANAT)
# 739 : Peptidyl-prolyl cis-trans isomerase A
# 740 : Homoserine kinase
# 741 : dCTP pyrophosphatase 1 (DCTPP1)
# 742 : Prostanoid EP2 Receptor
# 743 : Prostanoid EP3 Receptor
# 744 : PTGFR
# 745 : Thromboxane Alpha
# 746 : GABA A receptor alpha-5/beta-3/gamma-2
# 747 : GALR3
# 748 : Neuronal acetylcholine receptor
# 749 : Neuronal acetylcholine receptor; alpha2/beta2
# 750 : Imidazoline I1
# 751 : ADRA2A
# 752 : Cyclooxygenase-1 (COX-1)
# 753 : Aromatase cytochrome P450
# 754 : Dihydroorotase (DHO)
# 755 : Dipeptidyl peptidase III
# 756 : Apoptosis Regulator Bcl-xL
# 757 : MurC
# 758 : Glutamine synthetase
# 759 : beta-glucosidase
# 760 : Glucosamine-6- Phosphate Synthase
# 761 : Somatostatin receptor type 5
# 762 : EDNRB
# 763 : OPRD1
# 764 : Mu-type opioid receptor
# 765 : PTGER3
# 766 : NPY2R
# 767 : PPYR1
# 768 : C5a anaphylatoxin chemotactic receptor (C5aR)
# 769 : Motilin
# 770 : Histamine H2 Receptor
# 771 : Neutral Endopeptidase (NEP)
# 772 : Trypanothione Reductase (TR)
# 773 : S-Adenosylmethionine Synthase (AdoMet)
# 774 : 17-beta-hydroxysteroid dehydrogenase type 3
# 775 : Glycosylasparaginase (GA)
# 776 : BRS3
# 777 : Bombesin 4
# 778 : Cyclooxygenase
# 779 : F2RL1
# 780 : Adenosine receptor A2b
# 781 : Angiotensin IV
# 782 : Xanthine dehydrogenase/oxidase
# 783 : 5-Hydroxytryptamine receptor 7 (5-HT7)
# 784 : Neuronal acetylcholine receptor subunit alpha-3
# 785 : CNR1
# 786 : LTB4R
# 787 : GABA B rho 1
# 788 : Prostaglandin F2-alpha receptor
# 789 : Cysteinyl leukotriene receptor
# 790 : CYSLTR2
# 791 : P2X purinoceptor 1
# 792 : Metabotropic glutamate receptor 8 (mGlu8)
# 793 : Urease
# 794 : ADORA1
# 795 : ADORA3
# 796 : GPR145
# 797 : PGD2
# 798 : TRAR1
# 799 : CGRP
# 800 : RAMP1
# 801 : Neurotensin receptor 1
# 802 : NTSR2
# 803 : TACR2
# 804 : Adrenergic alpha1B
# 805 : GPR24
# 806 : Lipoxygenase
# 807 : TG 1019
# 808 : VIPR1
# 809 : KHEYLRF-NH2 (AF2)
# 810 : Angiotensin II receptor
# 811 : Glutathione S-transferase E2
# 812 : Lactate dehydrogenase A (LDHA)
# 813 : L-lactate dehydrogenase A
# 814 : NPFF
# 815 : NPFF2
# 816 : Glutamate delta 2
# 817 : alpha-1 Nicotinic AChR
# 818 : TRHR
# 819 : Thyrotropin-releasing hormone receptor
# 820 : GPR103
# 821 : Potassium channel (ATP modulatory)
# 822 : GABA A receptor alpha-3/beta-2/gamma-2
# 823 : Neuronal acetylcholine receptor subunit alpha-2
# 824 : Excitatory amino acid transporter 2
# 825 : MAP kinase-interacting serine/threonine-protein kinase 2
# 826 : Protein Disulfide-Isomerase (PDI)
# 827 : SLC6A4
# 828 : GRIK1
# 829 : P2X purinoceptor 3
# 830 : P2X purinoceptor 2
# 831 : Gastrin-Releasing peptide
# 832 : UTS2R
# 833 : Urotensin II receptor
# 834 : Serine/threonine-protein kinase Aurora-C
# 835 : Phosphodiesterase 11A (PDE11A)
# 836 : Solute carrier organic anion transporter family member 1B3 (OATP1B3)
# 837 : Melanocortin receptor 4
# 838 : Bile salt export pump (BSEP)
# 839 : Excitatory amino acid transporter 1
# 840 : Metabotropic glutamate receptor 5
# 841 : PKA
# 842 : ADRA1B
# 843 : GRIA1
# 844 : GRIA2
# 845 : Glucosamine-6-phosphate synthase
# 846 : Chymotrypsin
# 847 : 6-phosphogluconate dehydrogenase (6PGD)
# 848 : Glutathione oxidoreductase (GR)
# 849 : Phospholipase D2 (PLD2)
# 850 : nuclear receptor coactivator 3 isoform a
# 851 : Histone deacetylase 6
# 852 : Histone deacetylase 8
# 853 : Cholesteryl ester transfer protein
# 854 : 5-lipoxygenase/FLAP
# 855 : Leucine-rich repeat serine/threonine-protein kinase 2 (LRRK2)
# 856 : Histone-lysine N-methyltransferase EZH2
# 857 : Interleukin-6
# 858 : S-nitrosoglutathione reductase (GSNOR)
# 859 : Cyclophilin B (CypB)
# 860 : Cyclophilin A (CYPA)
# 861 : Tyrosyl-DNA phosphodiesterase 1 (TDP1)
# 862 : Sodium/calcium exchanger 1(NCX1)
# 863 : Trace amine-associated receptor 1 (TAAR1)
# 864 : Egl nine homolog 1
# 865 : High-affinity choline transporter
# 866 : 26S Proteasome regulatory subunit Rpn11 (Rpn11)
# 867 : TPA: Essential component of the Translocase of the Inner Mitochondrial membrane (TIM23 complex)
# 868 : DNA (cytosine-5)-methyltransferase 1 (DNMT1)
# 869 : Zinc finger protein GLI1
# 870 : Acetylcholine Binding protein
# 871 : Acetyl-coenzyme A transporter 1 (AT1)
# 872 : Serine/threonine-protein kinase TBK1
# 873 : Apoptosis regulator Bcl-2
# 874 : Sodium channel protein type 9 subunit alpha
# 875 : Isocitrate dehydrogenase [NADP] cytoplasmic
# 876 : Endothelial lipase
# 877 : Tyrosine-protein kinase JAK1
# 878 : RNA polymerase (NS5B)
# 879 : Plasma kallikrein
# 880 : Transcription initiation factor IIA
# 881 : sodium-dependent glucose cotransporter 2 (SGLT2)
# 882 : Transient receptor potential cation channel subfamily V member 3
# 883 : Cathepsin A (CTSA)
# 884 : Histidinol dehydrogenase
# 885 : Potassium channel protein TASK-1
# 886 : Small conductance calcium-activated potassium channel protein 3
# 887 : NF-kappa-beta-inducing kinase (NF-kB)
# 888 : P2X purinoceptor 7
# 889 : Tryptophanase
# 890 : Steroid 5-alpha-reductase
# 891 : Phosphodiesterase (TcrPDEC)
# 892 : PhoP
# 893 : Glycogen Synthase Kinase 3 (GSK3)
# 894 : Hypoxanthine-guanine-xanthine phosphoribosyltransferase (PfHGXPRT)
# 895 : Dual specificity mitogen-activated protein kinase kinase 6
# 896 : Cruzipain
# 897 : Pancreatic alpha-amylase
# 898 : AICAR transformylase
# 899 : Biotin ligase
# 900 : Protein RecA
# 901 : Beta-2-microglobulin
# 902 : HCV NS3 Proteinase
# 903 : Macrophage migration inhibitory factor (MIF)
# 904 : 5-hydroxytryptamine receptor 3A
# 905 : CaM-kinase kinase beta
# 906 : Trehalose Synthase (TreS)
# 907 : Beta-lactamase
# 908 : Myeloperoxidase (MPO)
# 909 : Phosphoehtnaolamine Methyltransferases 1 (PMT1)
# 910 : Bifunctional protein (GlmU)
# 911 : Ubiquitin activating enzyme (UAE)
# 912 : Acid phosphatase (acpA)
# 913 : Plasminogen activator inhibitor-1
# 914 : Matrix metalloproteinase-25
# 915 : Methyl-accepting chemotaxis protein (McpS)
# 916 : Cytochrome P450 2E1
# 917 : Endothelin-converting enzyme 2 (ECE-2)
# 918 : Cytochrome P450 144 (CYP144)
# 919 : Cytochrome P450 125 (CYP125)
# 920 : 3C-like proteinase (CVB3 3Cpro)
# 921 : Leukocyte common antigen
# 922 : Deoxyribonucleoside 5&#39;-monophosphate N-glycosidase (Rcl)
# 923 : Cytochrome P450 130
# 924 : Trypanothione synthetase (TryS)
# 925 : Serine/threonine-protein kinase MRCK alpha
# 926 : NAD synthetase
# 927 : Chemokine CXCL12
# 928 : Lecithin-cholesterol acyltransferase (LCAT)
# 929 : Tyrosine-protein kinase SYK
# 930 : NS3 Protein
# 931 : Casein kinase I isoform alpha
# 932 : Beta-adrenergic receptor kinase 1
# 933 : Trp Aprorepressor
# 934 : Reverse Transcriptase
# 935 : Ah Receptor
# 936 : Acyl-protein thioesterase 1
# 937 : Salicylate synthase (MbtI)
# 938 : Pentachlorophenol hydroxylase
# 939 : Cytochrome P450 24A1
# 940 : Cytochrome P450
# 941 : Lysine-specific demethylase 5A
# 942 : Nicotinamidase (BbNic)
# 943 : Nicotinamidase (PncA)
# 944 : Lysine-specific histone demethylase 1A
# 945 : Dihydrolipoyl dehydrogenase (Lpd)
# 946 : NS3 protein
# 947 : Dimethylarginine dimethylaminohydrolase 1 (DDAH)
# 948 : Poly(A)-specific ribonuclease (PARN)
# 949 : UDP-3-O-[3-hydroxymyristoyl] N-acetylglucosamine deacetylase (LxpC)
# 950 : NADH-ubiquinone oxidoreductase
# 951 : Thiamine-binding periplasmic protein
# 952 : Oxaloacetate decarboxylase (PA4872)
# 953 : Protein kinase C alpha
# 954 : Aspartokinase I
# 955 : Carbamoyl-phosphate synthase (H353N)
# 956 : DNA gyrase
# 957 : DNA repair and recombination protein (RadA)
# 958 : Beta-ketoacyl-ACP synthase (KasA)
# 959 : Anthranilate phosphoribosyltransferase (Mtb-AnPRT)
# 960 : Glucose-1-phosphate thymidylyltransferase (RmlA)
# 961 : Cysteine protease falcipain-2
# 962 : Cytochrome P450 1A1
# 963 : Src SH2 domain
# 964 : 3-dehydroquinate synthase
# 965 : Gag-Pol polyprotein (Capsid Protein)
# 966 : Serine/threonine-protein kinase CHK2
# 967 : Ephrin type-B receptor 3 (EPHB3)
# 968 : Lactate dehydrogenase (LDH)
# 969 : Beta amyloid A4 protein
# 970 : Cathepsin V
# 971 : SKiNhead family member (skn-1)
# 972 : endothelial PAS domain-containing protein 1
# 973 : C-X-C chemokine receptor type 5 isoform 1
# 974 : sentrin-specific protease 1
# 975 : Low molecular weight phosphotyrosine protein phosphatase (LMWPTP)
# 976 : hypothetical protein SA1422
# 977 : ADP-ribosylation factor GTPase-activating protein 1
# 978 : HIV-1 B HXB2-LAI-IIIB-BRU
# 979 : MSRA protein
# 980 : nuclear receptor subfamily 5 group A member 2 isoform 2
# 981 : methionyl-tRNA synthetase
# 982 : TCRAV4S1
# 983 : cyclic AMP receptor protein
# 984 : Galanin receptor 3
# 985 : nuclear receptor subfamily 0 group B member 1
# 986 : Endothelin-converting enzyme 1 (ECE)
# 987 : Serine/threonine-protein kinase ATR
# 988 : Orexin receptor type 2
# 989 : Orexin receptor type 2 (OX2)
# 990 : Monocyte chemotactic protein-1 (MCP-1)
# 991 : Enoyl-ACP reductase (ENR)
# 992 : Protease
# 993 : Glycine transporter 1
# 994 : Solute carrier family 22 member 12
# 995 : Transient receptor potential M8 protein (TRPM8)
# 996 : Rho-associated protein kinase 1 (ROCK1)
# 997 : Macrophage colony-stimulating factor 1 (CSF-1)
# 998 : Serine protease NS3
# 999 : Tyrosine-protein kinase Yes
# 1000 : MAP kinase-interacting serine/threonine-protein kinase 1
# 1001 : Dipeptidyl peptidase 2 (DPP II)
# 1002 : Nicotinamide adenine dinucleotide synthetase (NADs)
# 1003 : Translocator protein
# 1004 : Plasminogen activator urokinase
# 1005 : Macrophage colony-stimulating factor 1 receptor (c-Fms)
# 1006 : Beta-lactamase (AmpC)
# 1007 : COUP transcription factor 2 isoform a
# 1008 : Glucosamine synthetase
# 1009 : 5-enolpyruvylshikimate-3-phosphate synthase
# 1010 : Maternal embryonic leucine zipper kinase (MELK)
# 1011 : Eukaryotic translation initiation factor 4E (eIF4E)
# 1012 : Cyclin-dependent kinase 9
# 1013 : Hepatitis C virus NS5B RNA-dependent RNA polymerase
# 1014 : Calcitonin gene-related peptide type 1 receptor
# 1015 : Glycine transporter 1b
# 1016 : RNA-directed RNA polymerase (NS5B)
# 1017 : Hypoxia-inducible factor prolyl hydroxylase 4 (HIF)
# 1018 : C-C chemokine receptor type 1
# 1019 : Vascular adhesion protein 1 (VAP-1)
# 1020 : PKC alpha [mouse]
# 1021 : MAT2A
# 1022 : ALK1
# 1023 : Neuronal acetylcholine receptor subunit alpha-7
# 1024 : Sodium/glucose cotransporter 2 (SGLT2)
# 1025 : Peptidase 1 (Der p 1)
# 1026 : Estradiol 17-beta-dehydrogenase 1 (17beta-HSD1)
# 1027 : Tyrosine-protein kinase receptor FLT3
# 1028 : Jumonji domain-containing protein 2A (JMJD2A)
# 1029 : Jumonji domain-containing protein 2C (JMJD2C)
# 1030 : Human diphtheria toxin-like ADP-ribosyltransferase (ARTD3 or PARP3)
# 1031 : Factor D
# 1032 : Carbonic anhydrase 9
# 1033 : Fibroblast activation protein alpha
# 1034 : Autotaxin (mATX)
# 1035 : Autotaxin (zATX)
# 1036 : LecB
# 1037 : Siderocalin (Scn)
# 1038 : Death-associated protein kinase 1
# 1039 : DNA polymerase beta
# 1040 : DNA polymerase lambda
# 1041 : Penicillin binding protein 3 (PBP3)
# 1042 : Stearoyl-CoA desaturase 1 (SCD1)
# 1043 : Prolylcarboxypeptidase (PRCP)
# 1044 : Mitogen-activated protein kinase 9
# 1045 : gamma-Aminobutyric Acid Type B Receptor Subunit 1
# 1046 : H1N1 Endonuclease
# 1047 : Platelet-derived growth factor receptor alpha
# 1048 : Mast/stem cell growth factor receptor Kit
# 1049 : Retinol-binding protein 4
# 1050 : Xanthine dehydrogenase
# 1051 : 12-Lipoxygenase (12-LOX)
# 1052 : Thioredoxin reductase (TrxR)
# 1053 : Mcl-1 (residues 172-327)
# 1054 : Serine/threonine-protein kinase c-TAK1
# 1055 : Bradykinin-1 Receptor
# 1056 : Cyclin-dependent kinase 4 (CDK4)
# 1057 : Chorismate mutase (MTB CM)
# 1058 : 1-Deoxy-D-xylulose-5-phosphate synthase (DXP synthase))
# 1059 : Fatty-acid amide hydrolase (rFAAH&#8710;TM)
# 1060 : Histamine H3 receptor
# 1061 : Aldehyde dehydrogenase 3A1 (ALDH3A1)
# 1062 : Aldehyde dehydrogenase 1A1 (ALDH1A1)
# 1063 : Thrombin-activable fibrinolysis inhibitor (TAFIa)
# 1064 : Enteropeptidase
# 1065 : Calpain1/2
# 1066 : EGFR
# 1067 : Tyrosine-protein kinase CSK
# 1068 : NS3/4A protein
# 1069 : Serine/threonine-protein kinase/endoribonuclease IRE1 Alpha
# 1070 : RNAse A
# 1071 : Bcr-Abl
# 1072 : Cytidine deaminase (CDA)
# 1073 : Glucan Synthase
# 1074 : Phosphodiesterase 9A
# 1075 : NADPH-dependent enoyl-ACP reductase (FabI)
# 1076 : DOPA decarboxylase (DDC)
# 1077 : Beta-secretase 1 (BACE)
# 1078 : ALK tyrosine kinase receptor (L1196M)
# 1079 : &#945;-glucosidase
# 1080 : Tyrosine kinase receptor c-Met (c-Met)
# 1081 : Alpha-glucosidase A (&#945;-Gal A)
# 1082 : PvdQ
# 1083 : Disintegrin and metalloproteinase domain-containing protein 10 (ADAM10)
# 1084 : tyrosyl-DNA phosphodiesterase 2
# 1085 : Phospholipase C-beta-3
# 1086 : Prion protein
# 1087 : Group III secretory phopholipase A2
# 1088 : Methyl-CpG binding domain protein 2
# 1089 : protein artemis isoform a
# 1090 : lens epithelium-derived growth factor p75
# 1091 : Kinesin-5 motor protein (KSP)
# 1092 : Urea transporter A1 (UT-A1)
# 1093 : Phosphodiesterase 7
# 1094 : Ribosomal protein S6 kinase (P70S6K)
# 1095 : Phosphatidylinositol 3-kinase regulatory subunit alpha
# 1096 : 15-hydroxyprostaglandin dehydrogenase [NAD+]
# 1097 : Neuropeptide Y receptor type 5 (NPY Y5)
# 1098 : Aldehyde dehydrogenase (ALDH2)
# 1099 : Hypoxia-inducible factor prolyl hydroxylase 1
# 1100 : Prostaglandin E synthase
# 1101 : MurA (E. coli)
# 1102 : MurA (E. cloacae)
# 1103 : MurA (H. influenzae)
# 1104 : MurB (E. coli)
# 1105 : MurB (S. aureus)
# 1106 : MurE (E. coli)
# 1107 : MurE
# 1108 : MurE (M. tuberculosis)
# 1109 : MurF
# 1110 : MurF (S. pneumoniae)
# 1111 : Fatty acid synthase
# 1112 : Purinergic receptor P2Y12
# 1113 : Prostaglandin E2 receptor EP2 subtype
# 1114 : Prostaglandin E2 receptor EP4 subtype
# 1115 : Prostanoid EP1 receptor
# 1116 : DNA primase (Ba DnaG)
# 1117 : Enoyl-acyl carrier reductase
# 1118 : Liver fatty acid binding protein (human L-FABP T94T)
# 1119 : acyl coA-diacylglycerol acyl transferase 1 (DGAT1)
# 1120 : Thrombin-activatable fibrinolysis (TAFI)
# 1121 : Prokineticin receptor 2 (PRK2)
# 1122 : Prokineticin receptor 1 (PRK1)
# 1123 : Mineralocorticoid receptor
# 1124 : Hypoxia-inducible factor (HIF-PH2)
# 1125 : C-C chemokine receptor type 3
# 1126 : MurC (P. aeruginosa)
# 1127 : CDC7/DBF4 (Cell division cycle 7-related protein kinase/Activator of S phase kinase)
# 1128 : NS3-4A protease
# 1129 : G-protein coupled receptor 4 (GPR4)
# 1130 : Core-binding factor subunit beta (CBFB)
# 1131 : Phosphodiesterase 1C (PDE1C)
# 1132 : Phospholipase D (PLD_sp)
# 1133 : 20S proteasome chymotrypsin-like
# 1134 : Eukaryotic elongation factor 2 kinase
# 1135 : Serine/threonine-protein kinase ILK-1
# 1136 : Cytochrome P450 2C9
# 1137 : Receptor-type tyrosine-protein phosphatase F (LAR)
# 1138 : Disintegrin and metalloproteinase domain-containing protein 33
# 1139 : Calcitonin gene-related peptide (CGRP alpha)
# 1140 : Cyclin-T1
# 1141 : Matrix metallopeptidase 13 (MMP13)
# 1142 : Trypanosoma brucei RNA editing ligase 1
# 1143 : Transthyretin
# 1144 : Interleukin-2 (IL-2)
# 1145 : Mitogen-activated protein kinase kinase kinase 5 (MAP3K5)
# 1146 : Beta-secretase 2
# 1147 : Kaposi&#39;s sarcoma-associated herpesvirus protease (KSHV Pr)
# 1148 : Arginase (SmARG)
# 1149 : C-C chemokine receptor type 2
# 1150 : Ketohexokinase
# 1151 : Serine/threonine-protein kinase receptor R3
# 1152 : Sodium/glucose cotransporter 1 (SGLT1)
# 1153 : Uridine phosphorylase (UPase)
# 1154 : Proteinase-activated receptor 1
# 1155 : 5-hydroxytryptamine receptor 1A (5HT1A)
# 1156 : Regulator of G-protein signaling 4 (RGS4)
# 1157 : Pyruvate dehydrogenase kinase isoform 2 (PDHK2)
# 1158 : Transporter
# 1159 : Poly [ADP-ribose] polymerase 1 (Parp1)
# 1160 : Pyruvate kinase (PKM2)
# 1161 : Neuraminidase
# 1162 : Prostaglandin E2 receptor EP1 subtype (EP1)
# 1163 : hEP3D/ hEP3A
# 1164 : DNA Gyrase Subunit A
# 1165 : Serine/threonine-protein kinase PLK2
# 1166 : Nuclear receptor ROR-gamma
# 1167 : Bradykinin B1 receptor
# 1168 : Calcium release-activated calcium (CRAC)
# 1169 : Endothelial lipase (EL)
# 1170 : NAD kinase 1 (NADK1)
# 1171 : Integrin alpha-5
# 1172 : Tau Protein Kinase 1 (TPK1)
# 1173 : GABA A receptor alpha-2/beta-2/gamma-2
# 1174 : Peptidylarginine deiminase 4 (PAD4)
# 1175 : EML4 ALK Fusion Protein
# 1176 : Phosphodiesterase 10A (PDE10A)
# 1177 : Signal transducer and activator of transcription 3
# 1178 : Prostaglandin transporter (PGT)
# 1179 : 5-lipoxygenase-activating protein (FLAP)
# 1180 : O-GlcNAc Transferase (OGT)
# 1181 : PDZ-binding kinase
# 1182 : Stearoyl-CoA desaturase 1
# 1183 : Potassium voltage-gated channel subfamily H member 2
# 1184 : Calcium/calmodulin-dependent protein kinase type II subunit delta
# 1185 : Bromodomain-containing protein 4
# 1186 : Coagulation factor IX
# 1187 : Nuclear factor NF-kappa-B
# 1188 : Monoglyceride lipase
# 1189 : Death-associated protein kinase 1 (DAPK1)
# 1190 : Juvenile hormone epoxide hydrolase (JHEH)
# 1191 : Thiamine transporter (ThiT)
# 1192 : PNAG de-N-acetylase (PgaB)
# 1193 : Peptidoglycan de-N-acetylase (PgdA)
# 1194 : Integrase
# 1195 : Transient receptor potential cation channel subfamily M member 8 (TRPM8)
# 1196 : Menin
# 1197 : Thymidine phosphorylase (TP)
# 1198 : Chitin synthase (CS)
# 1199 : Beta-glucuronidase (&#946;-glucuronidase)
# 1200 : DENV2 protease (NS2B-NS3)
# 1201 : N-terminal nucleophile hydrolase (PVdQ)
# 1202 : ADC-7 beta-lactamase (ADC-7)
# 1203 : SHV-1 beta-lactamase
# 1204 : Mandelate racemase (MR)
# 1205 : Eis_Ban acetyltransferase (Eis_Ban)
# 1206 : Nitric oxide synthase (bsNOS)
# 1207 : Cysteine protease SpeB (SpeB)
# 1208 : Acetylpolyamine amidohydrolase (APAH)
# 1209 : Class A beta-lactamase BlaC (BlaC)
# 1210 : Heat-shock protein 90 (Hsp90)
# 1211 : Protein Kinase CK2 (CK2&#945;)
# 1212 : Acyl-CoA:monoacylglycerol acyltransferase 2 (MOGAT2)
# 1213 : Acetyl-CoA carboxylase 1 (ACC1)
# 1214 : Calcium release-activated calcium channel
# 1215 : Intestinal fatty acid-binding protein (hIFABP)
# 1216 : cis-Decaprenyl diphosphate synthase (cis-DPPS)
# 1217 : cis-Farnesyl diphosphate synthase (cis-FPPS)
# 1218 : 15-Lipoxygenase-2 (15-LOX-2)
# 1219 : Class I phosphodiesterase B1 (TbrPDEB1)
# 1220 : Tyrosine-protein kinase receptor UFO
# 1221 : Metallo-beta-lactamase VIM-2 (VIM-2)
# 1222 : PKC alpha and beta-2
# 1223 : Platelet-activating factor acetylhydrolase 1b2 (PAFAH1b2)
# 1224 : Methyl-lysine binding protein (53BP1)
# 1225 : C-terminal-binding protein 2 (CtBP2)
# 1226 : 20S proteasome
# 1227 : AMP deaminase 1 (hAMPD1)
# 1228 : Extracellular signal-regulated kinase 1 (ERK1)
# 1229 : Tau protein kinase 1 (TPK1)
# 1230 : Ectonucleotide pyrophosphatase/phosphodiesterase family member 2
# 1231 : Beta-amyloid protein 42
# 1232 : Renal Outer Medullary Potassium (ROMK)
# 1233 : Baculoviral IAP repeat-containing protein 2
# 1234 : Thioredoxin reductase 1 (TrxR)
# 1235 : Gamma-secretase
# 1236 : Ileal bile acid transporter/bile acid cotransporter
# 1237 : Gonadotropin releasing hormone 1 (GnRHR1)
# 1238 : Activin receptor type-1
# 1239 : Pyruvate dehydrogenase kinase isoenzyme 1 (PDK1)
# 1240 : Histone deacetylase 2
# 1241 : SUMO-activating enzyme
# 1242 : C-C chemokine receptor type 5
# 1243 : Voltage-gated sodium channel subunit alpha Nav1.8
# 1244 : Transient receptor potential cation channel subfamily A member 1
# 1245 : Fibroblast growth factor receptor 2
# 1246 : Sodium channel protein type 5 subunit alpha
# 1247 : Apoptosis Signal-regulating Kinase 1 (ASK1)
# 1248 : G-protein- coupled-like receptor Smoothened (Smo)
# 1249 : HDAC1/NCOR2
# 1250 : Beta-glucuronidase (CpGUS)
# 1251 : Beta-glucuronidase (EcGUS)
# 1252 : Pancreatic alpha-amylase (HPA)
# 1253 : Leucyl-tRNA synthetase (LeuRS)
# 1254 : Human diphtheria toxin-like ADP-ribosyltransferase (ARTD6 or PARP5b)
# 1255 : 8-Oxoguanine DNA glycosylase-1 (OGG1)
# 1256 : HIV-1 Reverse transcriptase (HIV-1 RT)
# 1257 : Discoidin domain-containing receptor 2
# 1258 : Transcription factor STAT5a (STAT5a)
# 1259 : Transcription factor STAT5b (STAT5b)
# 1260 : Rhomboid protease (AaROM)
# 1261 : Rhomboid protease (AfROM)
# 1262 : Rhomboid protease (TmROM)
# 1263 : Beta-secretase 2 (BACE2)
# 1264 : Beta-secretase 1 (BACE1)
# 1265 : chemokine (C-X-C motif) receptor 3
# 1266 : Dipeptidyl peptidase-IV (DDP-4)
# 1267 : DNA gyrase subunit B (DNA gyraseB)
# 1268 : 11-beta-hydroxysteroid dehydrogenase 2
# 1269 : Aurora B/Incenp
# 1270 : Ribosomal protein S6 kinase alpha-3
# 1271 : Phosphodiesterase 1A (PDE1A)
# 1272 : Interleukin-1 receptor-associated kinase 4
# 1273 : Cytochrome P450 1A
# 1274 : Cytochrome P450 2D6 (2D6)
# 1275 : Voltage-gated sodium channel subunit alpha Nav1.4
# 1276 : Thyroid-stimulating hormone receptor (TSH)
# 1277 : Nuclear factor NF-kappa-B (NF-kB)
# 1278 : Nicotinamide N-methyltransferase (NNMT)
# 1279 : Taste receptor type 2 member 14
# 1280 : CD63 antigen
# 1281 : Soluble epoxide hydrolase (sEH)
# 1282 : Casein kinase II subunit beta (CK2 beta)
# 1283 : Aldo-keto reductase family 1 member C4 (AK1C4)
# 1284 : Prostaglandin G/H synthase (Cyclooxygenase-2)
# 1285 : Epidermal growth factor receptor (T790M)
# 1286 : Carbonic anhydrase 3 (CA III)
# 1287 : Phosphoinositide 3-kinases (PI3K)
# 1288 : Alpha-synuclein
# 1289 : Tau
# 1290 : Von Hippel-Lindau disease tumor suppressor protein (VBC)
# 1291 : Chemokine receptor type 1 (CXCR1)
# 1292 : Histone deacetylase 3
# 1293 : Polyphenol oxidase (PPO)
# 1294 : Urea Amidohydrolase Subunit alpha
# 1295 : CAM-RNase A
# 1296 : Eosinophil-derived neurotoxin (EDN)
# 1297 : TRAF2 and NCK-interacting protein kinase (TNIK)
# 1298 : 3-hydroxy-3-methylglutaryl-coenzyme A reductase (HMG-CoA)
# 1299 : Na/K-ATPase
# 1300 : Aldehyde oxidase (AO)
# 1301 : Beta-glucocerebrosidase
# 1302 : Focal adhesion kinase (FAK)
# 1303 : Purinergic receptor P2Y1
# 1304 : Monoamine oxidase B (MAO-B)
# 1305 : Aquaporin-1 (AQP1)
# 1306 : Protein-arginine N-methyltransferase 1
# 1307 : Beta-lactamase (TEM-1)
# 1308 : H4-BRD4
# 1309 : HDAC4 and MEF2D Protein
# 1310 : cFMS
# 1311 : o-Succinylbenzoyl-CoA synthase (MenE)
# 1312 : Dual specificty protein kinase CLK1
# 1313 : L&#8208;Hydroxynicotine oxidase (LHNO)
# 1314 : beta-Hydroxyacyl-acyl carrier protein dehydratase (YpFabZ)
# 1315 : Fat mass and obesity associated protein (FTO)
# 1316 : Cytosolic phosphoenolpyruvate carboxykinase (cPEPCK)
# 1317 : Porphobilinogen deaminase (PBGD)
# 1318 : Prostaglandin E synthase 2
# 1319 : Acyl Cholesterol Acyltransferase 1 (ACAT-1)
# 1320 : Ribosomal protein S6 kinase alpha 2
# 1321 : Insulin-like growth factor 1 receptor (964-1370)
# 1322 : Neuronal acetylcholine receptor subunit alpha-4 beta 2
# 1323 : N-myristoyltransferase (NMT1)
# 1324 : Ferrochelatase R115L (FECH)
# 1325 : Thioesterase PqsE (PqsE)
# 1326 : Coagulation factor XIII A (FXIIIa)
# 1327 : Transglutaminase-1 (TG1)
# 1328 : Plasma amine oxidase (BPAO)
# 1329 : Proto-oncogene tyrosine-protein kinase Src (c-Src)
# 1330 : Tyrosine-protein kinase ABL1 (c-Abl)
# 1331 : Transglutaminases (TGase)
# 1332 : Cell division protein FtsZ
# 1333 : Dual-specificity tyrosine-phosphorylation regulated kinase 1A
# 1334 : 5-hydroxytryptamine receptor 2A (5HT2A)
# 1335 : 5-hydroxytryptamine receptor 2B (5HT2B)
# 1336 : Dopamine D4 receptor
# 1337 : Sepiapterin reductase (SPR)
# 1338 : Pyruvate dehydrogenase (PDH)
# 1339 : Lipoamide Dehydrogenase (Lpd)
# 1340 : Isoleucyl-tRNA synthetase (IleRS)
# 1341 : Pantothenate kinase (PanK)
# 1342 : CREB-binding protein
# 1343 : Glucose Transporter 1 (hGLUT1)
# 1344 : Sonic hedgehog protein
# 1345 : Thyroid-stimulating hormone subunit beta (bTSH)
# 1346 : Mitotic kinesin Eg5 (Eg5)
# ...
# 3622 : Thymidine kinase 2
# 3623 : Hexokinase type II
# 3624 : Mono [ADP-ribose] polymerase PARP16
# 3625 : Protein arginine methyltransferase 7 (PRMT7)
# 3626 : Nicotinic acetylcholine receptor alpha6/alpha3/beta4
# 3627 : IL15-IL15 receptor
# 3628 : Interleukin-15
# 3629 : Interleukin-2
# 3630 : Angiotensin-converting enzyme-related carboxypeptidase
# 3631 : Lactoperoxidase (LPO)
# 3632 : Pepsinogen C
# 3633 : Snake venom metalloproteinase Bap1
# 3634 : Integrin alpha-V/beta-3/alpha-V/beta-5
# 3635 : BCoR-BCL6
# 3636 : Zinc finger and BTB domain-containing protein 16
# 3637 : D2-like dopamine receptor
# 3638 : Anoctamin-1
# 3639 : SHMT
# 3640 : Nucleotide-binding oligomerization domain-containing protein 2
# 3641 : Histone deacetylase 1/2/3/6
# 3642 : S-methyl-5-thioadenosine phosphorylase
# 3643 : Hypoxia-inducible factor prolyl hydroxylase
# 3644 : Matrix metalloproteinase 14
# 3645 : Alpha-mannosidase 2C1
# 3646 : Meprin A subunit beta
# 3647 : ELAV-like protein 3
# 3648 : Wee1-like protein kinase 2
# 3649 : Cathepsin E
# 3650 : Lysosomal phospholipase A1
# 3651 : DNA repair protein complementing XP-A cells
# 3652 : Leucine--tRNA ligase
# 3653 : Phosphodiesterase 6C (PDE6C)
# 3654 : RAS guanyl-releasing protein 1
# 3655 : CDK19/Cyclin C
# 3656 : Rap guanine nucleotide exchange factor 3
# 3657 : Dipeptidyl peptidase II and dipeptidyl peptidase IV (DPP2 and DPP4)
# 3658 : GABA receptor alpha-1 subunit
# 3659 : Neurotrophic tyrosine kinase receptor
# 3660 : Sialidase A
# 3661 : Neuraminidase A (NanA)
# 3662 : Basic phospholipase A2 VRV-PL-VIIIa
# 3663 : Chitinase 1
# 3664 : Chitotriosidase-1
# 3665 : JAK1/TYK2
# 3666 : Carbonic anhydrase 13 (CA XIII)
# 3667 : C-X-C chemokine receptor type 4
# 3668 : DCN1-like protein 1
# 3669 : Multidrug translocase mdfA
# 3670 : G-protein coupled receptor 84
# 3671 : Protein arginine N-methyltransferase 1
# 3672 : 14-3-3 protein zeta/delta
# 3673 : NIcotinic acetylcholine receptor alpha-3/beta-4/alpha-5
# 3674 : Carnitine acetylase
# 3675 : Protein arginine N-methyltransferase 3
# 3676 : Glutamate dehydrogenase
# 3677 : DNA cross-link repair 1A protein
# 3678 : 5' exonuclease Apollo
# 3679 : Envelope glycoprotein
# 3680 : Polyketide synthase Pks13
# 3681 : Canalicular multispecific organic anion transporter 2
# 3682 : Canalicular multispecific organic anion transporter 1
# 3683 : NUAK family SNF1-like kinase 1
# 3684 : Alcohol sulfotransferase
# 3685 : Ubiquitin-conjugating enzyme E2 D3
# 3686 : GATA4/NKX2-5
# 3687 : Homeobox protein Nkx-2.5
# 3688 : Cyclic GMP-AMP synthase
# 3689 : Acid-sensing ion channel 1
# 3690 : Heme ligase
# 3691 : P-selectin
# 3692 : Malate dehydrogenase cytoplasmic
# 3693 : GABA transporter 2
# 3694 : 3-beta-hydroxysteroid dehydrogenase/delta 5-->4-isomerase type I
# 3695 : Serine/threonine-protein kinase PAK7
# 3696 : Dual specificity phosphatase Cdc25C
# 3697 : Serine/threonine-protein kinase Chk1/2
# 3698 : TLR7 and TLR8
# 3699 : Tyrosine-protein kinase FER
# 3700 : Ornithine carbamoyltransferase
# 3701 : Tetanus toxin
# 3702 : Carbonic anhydrase-related protein 11
# 3703 : Phosphatidylcholine:ceramide cholinephosphotransferase 2
# 3704 : Spermidine/spermine N(1)-acetyltransferase 1
# 3705 : Small conductance calcium-activated potassium channel protein 1 (KCa2.1)
# 3706 : Glyceraldehyde-3-phosphate dehydrogenase cytosolic
# 3707 : N+/K+ ATPase alpha-4/beta-1
# 3708 : Na+/K+ ATPase alpha-2/beta-1
# 3709 : Na+/K+ ATPase alpha-1/beta-1
# 3710 : Ionotropic glutamate receptor NMDA1/2B
# 3711 : G protein-coupled receptor 80
# 3712 : Phosphoribosyl pyrophosphate synthetase-associated protein 2
# 3713 : CDC45-related protein
# 3714 : Vesicular glutamate transporter 3
# 3715 : Penicillopepsin
# 3716 : Saccharopepesin
# 3717 : Kallikrein-12
# 3718 : Matrix M2-1
# 3719 : Mitogen-activated protein kinase 2
# 3720 : Disintegrin and metalloproteinase domain-containing protein 9 (ADAM9)
# 3721 : Serine/threonine protein phosphatase PP1-gamma catalytic subunit
# 3722 : Alpha-1-acid glycoprotein 1
# 3723 : Eukaryotic translation initiation factor 2-alpha kinase 3
# 3724 : NH(3)-dependent NAD(+) synthetase
# 3725 : Poly [ADP-ribose] glycohydrolase
# 3726 : Constitutive androstane receptor
# 3727 : HPr kinase
# 3728 : Falcipain 2
# 3729 : Serine/threonine-protein kinase WNK1
# 3730 : Adenylosuccinate synthetase 2
# 3731 : Adenylate cyclase type V
# 3732 : Interleukin-2 receptor alpha chain
# 3733 : Hypoxanthine-guanine phosphoribosyltransferase
# 3734 : Dual specificity protein kinase CLK3
# 3735 : 1-deoxyxylulose-5-phosphate reductoisomerase
# 3736 : Human T-cell leukemia virus type I protease
# 3737 : Serotonin 3 (5-HT3) receptor
# 3738 : Lysozyme(L99A)
# 3739 : Lysozyme(L99A/M102Q)
# 3740 : Neuronal acetylcholine receptor protein alpha-2 subunit/subunit beta-4
# 3741 : Neuronal acetylcholine receptor protein beta-2 subunit/protein beta-3 subunit/subunit alpha-3/subunit alpha-6
# 3742 : C-8 sterol isomerase
# 3743 : Amine oxidase
# 3744 : Cell division protein zipA
# 3745 : Adenylate cyclase type II
# 3746 : Epididymis-specific alpha-mannosidase
# 3747 : CD209 antigen
# 3748 : G-protein coupled receptor 4
# 3749 : NADH-ubiquinone oxidoreductase MLRQ subunit
# 3750 : cGMP-gated cation channel alpha 1
# 3751 : Vacuolar-type proton translocating pyrophosphatase 1
# 3752 : ATP-dependent RNA helicase DDX39A
# 3753 : Beta-amylase
# 3754 : 3-oxoacyl-[acyl-carrier-protein] synthase 2
# 3755 : 3-oxoacyl-[acyl-carrier-protein] synthase 1
# 3756 : Cysteine protease
# 3757 : Dynein heavy chain
# 3758 : Falcipain 2B
# 3759 : Solute carrier family 22 member 3
# 3760 : Enterobactin synthetase component E
# 3761 : Calcium sensing receptor
# 3762 : Ketopantoate reductase
# 3763 : Aminoglycoside acetyltransferase
# 3764 : Poliovirus type 1 polyprotein
# 3765 : Vasoactive intestinal polypeptide receptor 2
# 3766 : MurA (P. aeruginosa)
# 3767 : UDP-glucose 4-epimerase
# 3768 : Cystathionine beta-lyase metC
# 3769 : RmtA
# 3770 : Creatine kinase M-type
# 3771 : Cytochrome P450 27B1
# 3772 : SHV-5 extended spectrum beta-lactamase
# 3773 : Integrin alpha2
# 3774 : Potassium voltage-gated channel subfamily B member 1
# 3775 : IAG-nucleoside hydrolase
# 3776 : Phosphoenolpyruvate carboxykinase cytosolic
# 3777 : Enoyl-ACP Reductase (FabK)
# 3778 : Cyclin-T1/Cyclin-dependent-like kinase 5
# 3779 : Dehydrogenase/reductase SDR family member 9
# 3780 : S-adenosyl-L-methionine:delta24-sterol-C-methyltransferase
# 3781 : Core antigen
# 3782 : Urokinase-type plasminogen activator (uPA)
# 3783 : Sensor histidine kinase yycG
# 3784 : Diacylglycerol kinase 1
# 3785 : Orotidine phosphate decarboxylase
# 3786 : DNA-directed RNA polymerase
# 3787 : Undecaprenyl pyrophosphate synthase
# 3788 : ADP-ribosylation factor 1
# 3789 : Cytochrome P450 165B3
# 3790 : Insulin-like growth factor II receptor
# 3791 : PhzR
# 3792 : Mitogen-activated protein kinase 8
# 3793 : Signal peptide peptidase-like 2A
# 3794 : Proline iminopeptidase
# 3795 : Bifunctional coenzyme A synthase
# 3796 : Solute carrier family 22 member 5
# 3797 : Non-specific lipid-transfer protein
# 3798 : Glycogen debranching enzyme
# 3799 : MAP kinase-interacting serine/threonine-protein kinase 1/2
# 3800 : Dual specificity mitogen-activated protein kinase kinase 4
# 3801 : Nicotinic acetylcholine receptor alpha1 subunit
# 3802 : Coagulation factor V
# 3803 : Peptidyl-prolyl cis-trans isomerase Mip
# 3804 : RyR1/FKBP12
# 3805 : Tripeptidyl-peptidase 2
# 3806 : Muscarinic acetylcholine receptor M2 and M5
# 3807 : Muscarinic acetylcholine receptor M1 and M3
# 3808 : Enoyl-[acyl-carrier-protein] reductase [NADH]
# 3809 : B-N-acetylhexosaminidase
# 3810 : Squalene epoxidase
# 3811 : Glycylpeptide N-tetradecanoyltransferase
# 3812 : Neutrophil elastase
# 3813 : Solute carrier family 22 member 20
# 3814 : Solute carrier family 22 member 6
# 3815 : NAD-dependent deacetylase HST2
# 3816 : Aspartate-semialdehyde dehydrogenase
# 3817 : DNA polymerase catalytic subunit
# 3818 : Adenylate cyclase type 10
# 3819 : Ectonucleoside triphosphate diphosphohydrolase 8
# 3820 : Liver fatty acid binding protein (rat L-FABP)
# 3821 : Galectin-9
# 3822 : Galectin-7
# 3823 : Glycophorin-A
# 3824 : Beta-ketoacyl-ACP-synthase III
# 3825 : Melanocortin receptor (M4 and M5)
# 3826 : Multifunctional protein ADE2
# 3827 : Cation-dependent mannose-6-phosphate receptor
# 3828 : Cell division control protein 28
# 3829 : STAM-binding protein (AMSH)
# 3830 : COP9 signalosome complex subunit 5 (Csn5)
# 3831 : Cholinesterases; ACHE & BCHE
# 3832 : RAF serine/threonine protein kinase
# 3833 : Penicillin-binding protein 2X
# 3834 : Transcription factor HES-1
# 3835 : Beta-lactoglobulin
# 3836 : Succinyl-diaminopimelate desuccinylase
# 3837 : Nicotinate-nucleotide adenylyltransferase
# 3838 : Angiotensin type II receptor
# 3839 : Segment polarity protein dishevelled homolog DVL-2
# 3840 : Ras-related protein Rap-1A
# 3841 : Penicillin binding protein 2'
# 3842 : Lethal(3)malignant brain tumor-like protein 3 (L3MBTL3)
# 3843 : Cytochrome P450c11B3
# 3844 : Pleiotropic ABC efflux transporter of multiple drugs
# 3845 : Solute carrier family 15 member 2
# 3846 : Tyrosine-protein kinase BLK
# 3847 : EWS-Fli1 protein
# 3848 : ATP-dependent RNA helicase DDX1
# 3849 : Serine/threonine-protein kinase haspin
# 3850 : Sphingolipid delta(4)-desaturase DES1
# 3851 : ALK5
# 3852 : Hydroxyacid oxidase 2
# 3853 : Acylamino-acid-releasing enzyme
# 3854 : Relaxin receptor 1
# 3855 : Relaxin-3 receptor 1
# 3856 : PTGER2
# 3857 : Tyrosine-protein kinase receptor Tie-1
# 3858 : Regulator of G-protein signaling 8
# 3859 : Chondroitin sulfate N-acetylgalactosaminyltransferase 1
# 3860 : Membrane-bound lytic murein transglycosylase B
# 3861 : Kallikrein 6
# 3862 : Multidrug resistance-associated protein 5
# 3863 : Voltage-dependent N-type calcium channel subunit alpha-1B
# 3864 : Long-chain fatty acid transport protein 1
# 3865 : Natural resistance-associated macrophage protein 1
# 3866 : Subtilisin-like protease
# 3867 : Dual specificity protein phosphatase 6
# 3868 : Extracellular superoxide dismutase [Cu-Zn]
# 3869 : Intracellular chorismate mutase
# 3870 : Adrenaline alpha1
# 3871 : Monocarboxylate transporter 2
# 3872 : Multidrug resistance associated protein
# 3873 : Protein prune homolog
# 3874 : PTPsigma-(Brain)
# 3875 : Dual specificity protein phosphatase 4
# 3876 : Inward rectifier potassium channel 4
# 3877 : Asparagine synthetase
# 3878 : Sodium channel protein type VIII alpha subunit
# 3879 : Neutral ceramidase
# 3880 : Methionine synthase
# 3881 : Succinate receptor 1
# 3882 : 2-oxoglutarate receptor 1
# 3883 : T-cell surface antigen CD2
# 3884 : Tyrosine-protein phosphatase non-receptor type 12 (PTP-PEST)
# 3885 : Fanconi anemia group F protein
# 3886 : Sodium/glucose cotransporter 1
# 3887 : Sodium/glucose cotransporter 2
# 3888 : Urea transporter 1
# 3889 : S-methylmethionine--homocysteine S-methyltransferase BHMT2
# 3890 : Serine protease SplB
# 3891 : Probable G-protein coupled receptor 142
# 3892 : Glutathione peroxidase 1 (GPx)
# 3893 : UDP-3-O-acyl-N-acetylglucosamine deacetylase
# 3894 : ETS-related transcription factor Elf-3/Vitamin D3 receptor-interacting protein (ESX/MED23)
# 3895 : Cdc2-related kinase
# 3896 : DNA-dependent protein kinase (DNAPK)
# 3897 : &#946;-Carbonic anhydrase 2 (CA 2)
# 3898 : C-type lectin domain family 4 member K
# 3899 : Macrophage mannose receptor 1
# 3900 : C-type lectin domain family 4 member C
# 3901 : TGF-beta receptor type II
# 3902 : Sulfate anion transporter 1
# 3903 : Serine/threonine-protein kinase 33
# 3904 : Protein phosphatase methylesterase 1
# 3905 : trace amine-associated receptor 1
# 3906 : Influenza A virus Hemagglutinin
# 3907 : V-type proton ATPase subunit C
# 3908 : Angiogenin
# 3909 : Candidapepsin-2
# 3910 : Diacyl Glycerolacyltransferase 1 (DGAT-1)
# 3911 : Protein-tyrosine kinase 2-beta
# 3912 : Mitochondrial carnitine/acylcarnitine carrier protein
# 3913 : Mitogen-activated protein kinase kinase kinase 1
# 3914 : Signal peptidase I
# 3915 : Hydroxyacid oxidase 1
# 3916 : Thiopurine S-methyltransferase
# 3917 : 7-dehydrocholesterol reductase
# 3918 : HLA class I histocompatibility antigen A-3
# 3919 : CG8425-PA [Drosophila melanogaster]
# 3920 : CDK-interacting protein 1
# 3921 : NADP-dependent leukotriene B4 12-hydroxydehydrogenase
# 3922 : Mitochondrial complex II; succinate dehydrogenase
# 3923 : Melatonin 1C
# 3924 : Calcium-activated potassium channel subunit alpha-1
# 3925 : Glutamyl endopeptidase
# 3926 : Calcium-activated potassium channel alpha/beta 1
# 3927 : Eukaryotic translation initiation factor 2-alpha kinase 1
# 3928 : Aldehyde dehydrogenase
# 3929 : Transcriptional regulator ERG
# 3930 : Inositol phosphorylceramide synthase catalytic subunit AUR1
# 3931 : Potassium/sodium hyperpolarization-activated cyclic nucleotide-gated channel 1
# 3932 : Solute carrier organic anion transporter family member 1A3
# 3933 : Prostaglandin Transporter
# 3934 : Solute carrier organic anion transporter family member 1A1
# 3935 : 40S ribosomal protein S27
# 3936 : Transglutaminase-6 (TG6)
# 3937 : Transglutaminase-3 (TG3)
# 3938 : GTPase NRas
# 3939 : Activated CDC42 kinase 1
# 3940 : Fucosyltransferase 10
# 3941 : Calnexin
# 3942 : Uridine-cytidine kinase 1
# 3943 : Endopolygalactyuronase
# 3944 : Cysteine synthase
# 3945 : Cyclin-dependent kinase 6/G1/S-specific cyclin D1
# 3946 : Myc proto-oncogene protein
# 3947 : Emopamil-binding protein-like
# 3948 : Putative silent information regulator 2
# 3949 : D-beta-D-heptose 7-phosphate kinase
# 3950 : Thioredoxin
# 3951 : integrin alpha-L
# 3952 : Threonine--tRNA ligase
# 3953 : Cytochrome P450 2C11
# 3954 : Kynurenine--oxoglutarate transaminase 3
# 3955 : Voltage-gated sodium channel subunit alpha Nav1.3 (Nav1.3)
# 3956 : NEDD8-activating enzyme E1 regulatory subunit
# 3957 : Ubiquitin-like modifier-activating enzyme ATG7
# 3958 : O-acetylserine sulfhydrylase
# 3959 : Histo-blood group ABO system transferase
# 3960 : Steroid Delta-isomerase
# 3961 : Tyrosine-protein kinase ABL2
# 3962 : SH2 domain-containing protein 1A
# 3963 : Hepatocyte growth factor
# 3964 : PERQ amino acid-rich with GYF domain-containing protein 2
# 3965 : Palmitoyl-protein thioesterase 1
# 3966 : Purinergic receptor P2Y14
# 3967 : FkbO
# 3968 : Transmembrane protease serine 4
# 3969 : Sodium/iodide cotransporter
# 3970 : Ribonucleoside-diphosphate reductase subunit alpha
# 3971 : Streptokinase
# 3972 : C-X3-C chemokine receptor 1
# 3973 : JAK2/JAK1
# 3974 : Histamine H4 Receptor
# 3975 : Cyclin-K
# 3976 : Transcriptional activator Myb
# 3977 : Testis-specific serine/threonine-protein kinase 2
# 3978 : Poly [ADP-ribose] polymerase 6
# 3979 : p21-Activated kinase 3 (PAK3)
# 3980 : Transient receptor potential cation channel subfamily V member 6
# 3981 : 5&#39;-AMP-activated protein kinase subunit beta-1
# 3982 : CD81 antigen
# 3983 : Ileal sodium/bile acid cotransporter
# 3984 : N-arachidonyl glycine receptor
# 3985 : RocR
# 3986 : N-acylneuraminate-9-phosphatase
# 3987 : Tubulin polyglutamylase TTLL7
# 3988 : Myoglobin
# 3989 : I-kappa-B-alpha
# 3990 : Ubiquitin carboxyl-terminal hydrolase 5
# 3991 : Nuclear receptor corepressor 1
# 3992 : Kir3.1/Kir3.2
# 3993 : G protein-activated inward rectifier potassium channel 1
# 3994 : Sphingosine kinase 2 (SPHK2)
# 3995 : Uncharacterized protein
# 3996 : Centromere-associated protein E
# 3997 : Short transient receptor potential channel 6
# 3998 : Microtubule-associated serine/threonine-protein kinase 3
# 3999 : NMDA receptor subunit 2D (GluN2D)
# 4000 : Glutamate [NMDA] receptor subunit epsilon 4
# 4001 : Transcriptional regulator MvfR
# 4002 : Cyclophilin C (CypC)
# 4003 : C-C motif chemokine 2
# 4004 : MBT domain-containing protein 1 (MBTD1)
# 4005 : Scm-like with four MBT domains protein 1
# 4006 : 3-oxoacyl-(Acyl-carrier protein) reductase
# 4007 : Signal peptidase IB
# 4008 : Cytohesin-2
# 4009 : KiSS-1 receptor
# 4010 : Hepatic Lipase (HL)
# 4011 : Proline racemase
# 4012 : Fe(3+)-pyochelin receptor
# 4013 : Nicotinic acetylcholine receptor alpha6/alpha3/beta2/beta3
# 4014 : Nicotinic acetylcholine receptor alpha1/beta1/epsilon/delta
# 4015 : Nicotinic acetylcholine receptor alpha3/beta4/alpha5
# 4016 : Clathrin heavy chain 1
# 4017 : Transient receptor potential cation channel subfamily M member 2
# 4018 : Protein kinase N1
# 4019 : Protein-lysine 6-oxidase
# 4020 : Integrin alpha2/beta1
# 4021 : Prohormone convertase 2
# 4022 : Alkaline phosphatase placental type
# 4023 : Probable ubiquitin carboxyl-terminal hydrolase FAF-X
# 4024 : Alpha-ketoglutarate-dependent dioxygenase alkB homolog 3
# 4025 : DNA (cytosine-5)-methyltransferase 3-like
# 4026 : DNA-directed DNA/RNA polymerase mu
# Time taken for : 4026 is 615.2468090057373 Seconds

# %% [markdown]
# **Graph Building Phase-2**

# %%
target_list = list(df2['Target Name Assigned by Curator or DataSource'].unique())
df2['Target Name Assigned by Curator or DataSource'] = df2['Target Name Assigned by Curator or DataSource'].str.split(',')
df2 = (df2.set_index(['PubChem CID','min'])['Target Name Assigned by Curator or DataSource']
       .apply(pd.Series)
       .stack()
       .reset_index()
       .rename(columns={0:'Target Name Assigned by Curator or DataSource'})
      
      )
target_list = list(df2['Target Name Assigned by Curator or DataSource'].unique())
len(target_list)
# Out:
# 376

# %%
#PART 2 - Mixed Complex List
t1 = time.time()
ele = 1
part_2_dict = {}
for targ in target_list: 
    print(str(ele)+str(" : ") + str(targ))
    tmp = df2.loc[df2['Target Name Assigned by Curator or DataSource']==targ]
    tmp_ids = tmp['PubChem CID'].to_list()
    Central_Node = targ
    tmp_ids.append(Central_Node)
    B = nx.Graph()
    B.add_nodes_from(tmp_ids)
    tmp_ids.pop()
    for pid in tmp_ids:
        val = float(tmp.loc[tmp['PubChem CID']==pid]['min'])
        B.add_edge(Central_Node,pid,weight=val)
    part_2_dict['{}'.format(ele)] = B
    ele+=1
    '''if ele ==50:
        break'''
t2 = time.time()
print(str("Time taken for : ") +str(len(target_list))+" is "+str(t2-t1)+" Seconds")
save_obj(part_2_dict,'df2')
# Out:
# 1 : Protein Kinase C
# 2 :  alpha
# 3 : Myosin light chain kinase
# 4 :  smooth muscle
# 5 : Glycogen Synthase Kinase-3
# 6 :  beta
# 7 : Cytochrome P450 11B1
# 8 :  mitochondrial
# 9 : cGMP-dependent 3'
# 10 : 5'-cyclic phosphodiesterase
# 11 : cAMP-specific 3'
# 12 : 5'-cyclic phosphodiesterase 4A
# 13 : cGMP-specific 3'
# 14 : Dihydroorotate dehydrogenase (quinone)
# 15 : Calcium/calmodulin-dependent 3'
# 16 : 5'-cyclic nucleotide phosphodiesterase 1B
# 17 : Phosphatidylinositol 4
# 18 : 5-bisphosphate 3-kinase catalytic subunit gamma isoform
# 19 : c-Jun N-terminal kinase
# 20 :  JNK
# 21 : 17-beta-Hydroxysteroid Dehydrogenase 5 (17-beta-HSD5
# 22 :  AKR1C3)
# 23 : Nitric-oxide synthase
# 24 :  brain
# 25 : Indoleamine 2
# 26 : 3-dioxygenase 1
# 27 : Nitric Oxide Synthase
# 28 :  endothelial
# 29 : Estrogen-Related Receptor
# 30 : Glycogen phosphorylase
# 31 :  muscle form
# 32 : Malate Dehydrogenase
# 33 : Phospholipase A2
# 34 :  membrane associated
# 35 : 5-bisphosphate 3-kinase catalytic subunit alpha isoform
# 36 : Phosphoinositide 3-Kinase (PI3K)
# 37 :  gamma
# 38 : GABAA Receptor
# 39 :  alpha-1
# 40 :  beta-3
# 41 :  gamma-2
# 42 :  beta-2
# 43 :  alpha-4
# 44 : 5'-cyclic phosphodiesterase 4D
# 45 : 5'-cyclic phosphodiesterase 4B
# 46 : Retinoic Acid Receptor
# 47 : 2C-methyl-D-erythritol-2
# 48 : 4-cyclodiphosphate synthase (IspF)
# 49 : Nitric oxide synthase
# 50 :  inducible
# 51 : Chain A
# 52 :  Crystal Structure Of A Pantothenate Synthetase
# 53 :  Apo Enzyme In C2 Space Group
# 54 : tyrosine 3-monooxygenase/tryptophan 5-monooxygenase activation protein
# 55 :  gamma polypeptide
# 56 : nuclear receptor subfamily 4
# 57 :  group A
# 58 :  member 1
# 59 : Alkaline phosphatase
# 60 :  tissue-nonspecific isozyme
# 61 : Chain B
# 62 :  Rna Aptamer Complexed With Hiv-1 Rev Peptide
# 63 :  Nmr
# 64 :  7 Structures
# 65 : phosphatase
# 66 :  orphan 1
# 67 : eukaryotic translation initiation factor 4 gamma
# 68 :  1 isoform 4
# 69 : dTDP-4-dehydrorhamnose 3
# 70 : 5-epimerase RmlC
# 71 : cell division cycle 42 (GTP binding protein
# 72 :  25kDa)
# 73 : protein phosphatase 1
# 74 :  catalytic subunit
# 75 :  alpha isoform 3
# 76 : Homo sapiens furin (paired basic amino acid cleaving enzyme) (FURIN)
# 77 :  mRNA
# 78 : NACHT
# 79 :  LRR and PYD domains-containing protein 1 isoform 1
# 80 : exonuclease V (RecBCD complex)
# 81 :  alpha chain
# 82 : Cholinergic
# 83 :  muscarinic
# 84 : Inositol 1
# 85 : 4
# 86 : 5-trisphosphate 3-kinase (IP3K )
# 87 :  group VII (platelet-activating factor acetylhydrolase
# 88 :  plasma)
# 89 : Nociceptin/Orphanin FQ
# 90 :  NOP receptor
# 91 : Glutamate receptor ionotropic
# 92 :  kainate 2
# 93 : Purinergic
# 94 :  P2X2
# 95 :  Nicotinic Alpha2Beta2
# 96 : Gamma hydroxybutyric
# 97 :  GHB
# 98 :  Nicotinic Alpha6
# 99 : Phosphoinositide specific phospholipase C
# 100 :  PI-PLC
# 101 : poly(A) binding protein
# 102 :  cytoplasmic 1
# 103 : cAMP and cAMP-inhibited cGMP 3'
# 104 : 5'-cyclic phosphodiesterase 10A
# 105 : Glutaminase kidney isoform
# 106 : Alpha-(1
# 107 : 3)-fucosyltransferase VII
# 108 : Histone-lysine N-methyltransferase
# 109 :  H3 lysine-79 specific
# 110 : Procollagen-proline
# 111 : 2-oxoglutarate-4-dioxygenase
# 112 : 2
# 113 : 6-dichloro-p-hydroquinone 1
# 114 : 2-dioxygenase (PcpA)
# 115 :  Crystal Structure Of The B1b2 Domains From Human Neuropilin- 1
# 116 : arf-GAP with SH3 domain
# 117 :  ANK repeat and PH domain-containing protein 1 isoform 2
# 118 : Fructose-1
# 119 : 6-bisphosphate aldolase (FBA)
# 120 : Homo sapiens huntingtin (HTT)
# 121 : Interleukin-8 receptors
# 122 :  CXCR2
# 123 : 5-bisphosphate 3-kinase catalytic subunit delta isoform/gamma isoform
# 124 : Kynurenine/alpha-aminoadipate aminotransferase
# 125 : Chain E
# 126 :  Fragment Double-D From Human Fibrin
# 127 : Protein DAF-12
# 128 :  isoform a
# 129 : 5-bisphosphate 3-kinase catalytic subunit beta isoform
# 130 : alpha-2
# 131 : 3-sialyltransferase
# 132 : Secretory phospholipase A2
# 133 :  group V (sPLA2-V)
# 134 : Protein kinase B (Akt1 E49C
# 135 :  C296S
# 136 :  C310S and C344S )
# 137 : Valosin containing protein
# 138 :  p97 subunit
# 139 : Isoform 3 of cAMP-specific 3'
# 140 : Alpha-1
# 141 : 6-mannosyl-glycoprotein 2-beta-N-acetylglucosaminyltransferase
# 142 : 5-bisphosphate 3-kinase catalytic subunit alpha isoform (PI3K alpha)
# 143 : SYK RPA purified
# 144 :  truncated construct of Spleen Tyrosine Kinase aa 360-635
# 145 :  NMDA 2B
# 146 : 6-phosphofructo-2-kinase/fructose-2
# 147 : 6-bisphosphatase 3 (PFKFB3)
# 148 : 6-bisphosphatase 4 (PFKFB4)
# 149 : 6-bisphosphatase 1 (FBPase)
# 150 : 3
# 151 : 5
# 152 : 6-pentakisphosphate 2-kinase (IPK1)
# 153 : &#946;-1
# 154 : 4-Galactosyltransferase I (&#946;4GalT)
# 155 : Na
# 156 : K-ATPase &#945;1&#946;1
# 157 : Exo-1
# 158 : 5-&#945;-L-arabinofuranobiosidase (Arb93A)
# 159 : Epidermal growth factor receptor(L858R
# 160 :  T790M)
# 161 : N-type calcium channel subunits alpha 1B (Cav2.2)
# 162 :  Beta 3
# 163 :  and Alpha 2 Delta
# 164 :  delta
# 165 : NADH dehydrogenase [ubiquinone] flavoprotein 1
# 166 : Dihydrodipicolinate synthase-like
# 167 :  brain (nNOS)
# 168 : 5'-cyclic phosphodiesterase 4A isoform 3
# 169 : Serine hydroxymethyltransferase
# 170 :  CXCR1
# 171 : 3-mannosyl-glycoprotein 2-beta-N-acetylglucosaminyltransferase
# 172 : POU domain
# 173 :  class 5
# 174 :  transcription factor 1
# 175 : Interferon-induced
# 176 :  double-stranded RNA-activated protein kinase
# 177 : IDH2 (R172K
# 178 :  40-end)
# 179 : Tryptophan 2
# 180 : 3-dioxygenase
# 181 : 3'
# 182 : 5'-cyclic phosphodiesterase (PDE2A)
# 183 : 6-mannosyl-glycoprotein 2-beta-N-acetylglucosaminyltransferase (MGAT2)
# 184 :  CXCR1/CXCR2
# 185 : 5'-cyclic phosphodiesterase 4B (PDE4B2)
# 186 : Sodium channel alpha subunits; brain (Types I
# 187 :  II
# 188 :  III)
# 189 : Thymidine kinase
# 190 :  cytosolic
# 191 : Hepatitis C virus serine protease
# 192 :  NS3/NS4A
# 193 : Sterol O-acyltransferase
# 194 :  Soat
# 195 : 5-trisphosphate receptor
# 196 : Protein kinase C
# 197 :  eta
# 198 :  PKC; classical/novel
# 199 : Endothelin receptor
# 200 :  ET-A/ET-B
# 201 :  major isoenzyme
# 202 :  kainate
# 203 : Arachidonate 15-lipoxygenase
# 204 :  type II
# 205 : Lignostilbene alpha
# 206 :  beta-dioxygenase
# 207 : Serine/threonine protein phosphatase 2A
# 208 :  alpha isoform
# 209 : 3)-fucosyltransferase IV
# 210 :  PKC; classical
# 211 : Vacuolar H(+)-transporting ATPase 116 kDa subunit
# 212 :  a1 isoform
# 213 : Potassium channel
# 214 :  inwardly rectifying
# 215 :  subfamily J
# 216 :  member 11/Sulfonylurea receptor 2
# 217 : Intercellular adhesion molecule (ICAM-1)
# 218 :  Integrin alpha-L/beta-2
# 219 :  epsilon
# 220 : 5-bisphosphate 3-kinase catalytic subunit delta isoform
# 221 :  acidic
# 222 : Heat shock protein 75 kDa
# 223 : Glycine
# 224 :  non-strychnine
# 225 : Retinal rod rhodopsin-sensitive cGMP 3'
# 226 : 5'-cyclic phosphodiesterase subunit delta
# 227 : 5'-cyclic phosphodiesterase 4C
# 228 : 1-phosphatidylinositol-4
# 229 : 5-bisphosphate phosphodiesterase gamma-1
# 230 : 6-bisphosphatase
# 231 :  member 11/Sulfonylurea receptor 1
# 232 : 5-trisphosphate receptor type 3
# 233 : N-acetyllactosaminide alpha-1
# 234 : 3-galactosyltransferase
# 235 :  Nicotinic Muscle
# 236 : Carboxypeptidase N
# 237 :  NMDA 1
# 238 : Cytochrome P450
# 239 :  family 4
# 240 :  subfamily X
# 241 :  polypeptide 1
# 242 :  isoform CRA_c
# 243 : Thioredoxin reductase 1
# 244 :  cytoplasmic
# 245 : Aldehyde dehydrogenase 1
# 246 : IgE Fc receptor
# 247 :  alpha-subunit
# 248 : 25-hydroxyvitamin D-1 alpha hydroxylase
# 249 : Salicylate synthetase
# 250 :  Irp9
# 251 : 3)-fucosyltransferase 9
# 252 : UDP-N-acetylmuramoyl-L-alanyl-D-glutamate--2
# 253 : 6-diaminopimelate ligase
# 254 :  AMPA 2
# 255 : N-acetyllactosaminide beta-1
# 256 : 3-N-acetylglucosaminyltransferase 3
# 257 : Hypoxia inducible factors; HIF-1-alpha
# 258 :  HIF-2-alpha
# 259 : Succinate dehydrogenase cytochrome b560 subunit
# 260 : 6-bisphosphatase 2
# 261 : Fructose-bisphosphate aldoloase
# 262 :  glycosomal
# 263 : Oligopeptide transporter
# 264 :  kidney isoform
# 265 : K-ATPase isoform alpha-1 (&#945;1)
# 266 : ATPase (Na+
# 267 :  K+)
# 268 : Inosine-5'-monophosphate dehydrogenase
# 269 :  probable
# 270 :  AMPA 4
# 271 : Farnesyltransferase
# 272 :  putative
# 273 : LIP1
# 274 :  secretory lipase (Family 3)
# 275 : Beta-1
# 276 : 4-mannosyl-glycoprotein 4-beta-N-acetylglucosaminyltransferase
# 277 : cGMP-inhibited 3'
# 278 : 5'-cyclic phosphodiesterase B
# 279 : Branched-chain-amino-acid aminotransferase
# 280 : Ornithine aminotransferase
# 281 : Bifunctional methylenetetrahydrofolate dehydrogenase/cyclohydrolase
# 282 : Hydroxyacylglutathione hydrolase
# 283 : Beta-galactoside alpha-2
# 284 : 6-sialyltransferase 1
# 285 :  Nicotinic Alpha3Beta2
# 286 : 6-bisphosphatase 1
# 287 : Sodium/potassium/calcium exchanger 6
# 288 : Solute carrier family 2
# 289 :  facilitated glucose transporter member 1
# 290 : 1
# 291 : 3-beta-glucan synthase component GLS2
# 292 :  facilitated glucose transporter member 2
# 293 :  facilitated glucose transporter member 3
# 294 :  LRR and PYD domains-containing protein 3
# 295 : 3-beta-glucan synthase
# 296 : 4-hydroxy-2-oxoglutarate aldolase
# 297 : Aldehyde dehydrogenase
# 298 :  cytosolic 1
# 299 : V-type proton ATPase subunit B
# 300 :  brain isoform
# 301 : Fumarate hydratase
# 302 : 3-dioxygenase 2
# 303 : ATP synthase subunit beta
# 304 : 6
# 305 : 7-dimethyl-8-ribityllumazine synthase
# 306 : 5-trisphosphate receptor type 1
# 307 : 6-phosphogluconate dehydrogenase
# 308 :  decarboxylating
# 309 : 4-galactosyltransferase 1
# 310 : CMP-N-acetylneuraminate-beta-1
# 311 : 4-galactoside alpha-2
# 312 : 3-dihydroxybenzoate-AMP ligase
# 313 : Translation factor GUF1
# 314 : Sterol 26-hydroxylase
# 315 : 3-glucan synthase
# 316 : 4-Dihydroxy-2-naphthoyl-CoA synthase
# 317 : Triosephosphate isomerase
# 318 : Glyceraldehyde-3-phosphate dehydrogenase
# 319 : Amiloride-sensitive cation channel 2
# 320 :  neuronal
# 321 : 3-deoxy-D-arabino-heptulosonate 7-phosphate synthase
# 322 :  Phe-sensitive
# 323 : Hydrolase
# 324 :  alpha/beta hydrolase fold family
# 325 : Protoporphyrinogen oxidase
# 326 : PARP 1
# 327 :  2 and 3
# 328 : Type I inositol-1
# 329 : 5-trisphosphate 5-phosphatase
# 330 :  56 kDa regulatory subunit
# 331 : 5-trisphosphate binding protein
# 332 :  65 kDa regulatory subunit A
# 333 : DNA-directed RNA polymerase
# 334 : 5-bisphosphate 3-kinase catalytic subunit alpha isoform/[Pyruvate dehydrogenase (acetyl-transferring)] kinase isozyme 1
# 335 : Alpha-N-acetylgalactosaminide alpha-2
# 336 : 6-sialyltransferase III
# 337 : CMP-N-acetylneuraminate-beta-galactosamide-alpha-2
# 338 : 6-sialyltransferase
# 339 : Cytochrome P450 11B2
# 340 : Glutaminase liver isoform
# 341 : Phosphatidylinositol 3-kinase regulatory subunit beta/Phosphatidylinositol 4
# 342 : Malate dehydrogenase
# 343 : 3-beta-hydroxysteroid-delta(8)
# 344 : delta(7)-isomerase
# 345 : Amine oxidase
# 346 :  copper containing
# 347 : Peptide deformylase 1A
# 348 :  chloroplastic
# 349 : Leucyl-tRNA synthetase
# 350 : Glucoamylase
# 351 :  intracellular sporulation-specific
# 352 : Farnesyl synthetase
# 353 : Mannosyl-oligosaccharide alpha-1
# 354 : 2-mannosidase isoform B
# 355 : Fatty acid-binding protein
# 356 :  adipocyte
# 357 : 5'-cyclic phosphodiesterase 7B
# 358 : Thymidylate kinase
# 359 : Carnitine O-palmitoyltransferase 1
# 360 :  liver isoform
# 361 :  muscle isoform
# 362 : Dihydropteroate synthetase
# 363 : ATP synthase subunit gamma
# 364 : Acyl carrier protein
# 365 : Succinate dehydrogenase [ubiquinone] iron-sulfur subunit
# 366 : Acetolactate synthase catalytic subunit
# 367 : 3-galactosyltransferase 1
# 368 : Arginase-2
# 369 : Carbonic anhydrase 2
# 370 :  isoform A
# 371 : 2-C-methyl-D-erythritol 2
# 372 : 4-cyclodiphosphate synthase
# 373 : 6-phospho-1-fructokinase
# 374 : 3-hydroxyanthranilate 3
# 375 : 4-dioxygenase
# 376 : 4-glucan:maltose-1-phosphate maltosyltransferase
# Time taken for : 376 is 59.72543430328369 Seconds
